# %% [markdown]
# # Knowledge Base Completion (KBC) / Link Prediction with RDF2Vec

# %% [markdown]
# This notebook allows a fully automated run of RDF2vec link prediction and evaluation.
#
# ## Prerequisites (Linux/MacOS)
#
# - install kbc_rdf2vec ([https://github.com/janothan/kbc_rdf2vec](https://github.com/janothan/kbc_rdf2vec))
# - install kbc_evaluation ([https://github.com/janothan/kbc_evaluation/](https://github.com/janothan/kbc_evaluation/))
# - install jRDF2Vec and add the shell script to your path (see [here](https://github.com/dwslab/jRDF2Vec/blob/master/src/main/bin/jrdf2vec.sh)) - alternatively, you can modify the specified jrdf2vec command in this notebook to fit your path.
#
# The only thing you have to do before running the whole notebook is to set your `work_dir` in the cell below.

# %%
# TODO: Now let's decide on your directory where everything shall be written to (requires > 5Gb of disk space)
work_dir = "/work/jportisc/kbc_rdf2vec/strategy_grid_2/evaluation_2"

# %% [markdown]
# ## Let's Transform WN18 and FB15k Into NT Files

# %%
import sys
from kbc_rdf2vec.dataset import DataSet
import os

# create the directory if it does not exist yet
nt_dir = os.path.join(work_dir, "nt_files")
if not os.path.exists(nt_dir):
    os.makedirs(nt_dir)

DataSet.write_training_file_nt(data_set=DataSet.WN18, file_to_write=os.path.join(nt_dir, "WN18.nt"))
DataSet.write_training_file_nt(data_set=DataSet.FB15K, file_to_write=os.path.join(nt_dir, "FB15k.nt"))

# %% [markdown]
# ## Let's Train Embeddings with jRDF2Vec
#
# Train embeddings for WN18 by running the following line:
# ```
# !jrdf2vec -graph "./WN18.nt" -numberOfWalks 300 -threads 20 -depth 4 -walkDirectory <set manually or use generated statement> -trainingMode sg -dimension 200 -window 2 -epochs 25
# ```
#
# Train embeddings for FB15k by running the following line:
# ```
# !jrdf2vec -graph "./FB15k.nt" -numberOfWalks 300 -threads 20 -depth 4 -walkDirectory <set manually or use generated statement> -trainingMode sg -dimension 200 -window 2 -epochs 25
# ```
#
# If you are happy with the default RDF2Vec configuration, you do not have to do anything except for running the cells below.

# %%
number_of_walks = 2000
depth = 4
training_mode = "sg"
dimension = 200
window = 5
epochs = 25

configuration_string = f"""
Number of Walks:  {number_of_walks}
Depth:            {depth}
Training Mode:    {training_mode}
Dimension:        {dimension}
Window:           {window}
Epochs:           {epochs}
"""

# %%
import os
import io

print(configuration_string)
wn18_walk_path = os.path.join(work_dir, "wn18_walks")
wn_nt_path = os.path.join(nt_dir, "WN18.nt")

# !jrdf2vec -graph $wn_nt_path -numberOfWalks $number_of_walks -threads 20 -depth $depth -walkDirectory $wn18_walk_path -trainingMode $training_mode -dimension $dimension -window $window -epochs $epochs

with io.open(os.path.join(wn18_walk_path, "configuration.txt"), 'w+', encoding='utf8') as f:
    f.write(configuration_string)
# Out:
# Number of Walks:  2000
# Depth:            4
# Training Mode:    sg
# Dimension:        200
# Window:           5
# Epochs:           25
#
# The specified walk directory does not exist. Trying to make the directory.
# Using 20 threads for walk generation and training.
# Using vector dimension: 200
# Using depth 4
# Generating 2000 walks per entity.
# RDF2Vec Classic
#  INFO [main] (ParserManager.java:53) - Using NxParser.
#  INFO [main] (ParserManager.java:88) - Model read into memory.
# walkGeneration mode is null... Using default: RANDOM_WALKS_DUPLICATE_FREE
#  INFO [pool-1-thread-18] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 1000
#  INFO [pool-1-thread-18] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 1303255
#  INFO [pool-1-thread-1] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 2000
#  INFO [pool-1-thread-1] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 2616321
#  INFO [pool-1-thread-1] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 3000
#  INFO [pool-1-thread-1] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 3958960
#  INFO [pool-1-thread-20] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 4000
#  INFO [pool-1-thread-20] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 5290194
#  INFO [pool-1-thread-12] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 5000
#  INFO [pool-1-thread-12] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 6632344
#  INFO [pool-1-thread-13] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 6000
#  INFO [pool-1-thread-13] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 7946582
#  INFO [pool-1-thread-3] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 7000
#  INFO [pool-1-thread-3] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 9253568
#  INFO [pool-1-thread-5] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 8000
#  INFO [pool-1-thread-5] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 10586850
#  INFO [pool-1-thread-18] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 9000
#  INFO [pool-1-thread-18] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 11937911
#  INFO [pool-1-thread-5] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 10000
#  INFO [pool-1-thread-5] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 13285654
#  INFO [pool-1-thread-13] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 11000
#  INFO [pool-1-thread-13] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 14620017
#  INFO [pool-1-thread-9] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 12000
#  INFO [pool-1-thread-9] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 15993744
#  INFO [pool-1-thread-5] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 13000
#  INFO [pool-1-thread-5] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 17328729
#  INFO [pool-1-thread-14] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 14000
#  INFO [pool-1-thread-14] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 18662797
#  INFO [pool-1-thread-3] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 15000
#  INFO [pool-1-thread-3] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 20009508
#  INFO [pool-1-thread-15] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 16000
#  INFO [pool-1-thread-15] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 21334285
#  INFO [pool-1-thread-6] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 17000
#  INFO [pool-1-thread-6] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 22656634
#  INFO [pool-1-thread-1] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 18000
#  INFO [pool-1-thread-1] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 23951666
#  INFO [pool-1-thread-8] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 19000
#  INFO [pool-1-thread-8] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 25205935
#  INFO [pool-1-thread-2] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 20000
#  INFO [pool-1-thread-2] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 26572935
#  INFO [pool-1-thread-4] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 21000
#  INFO [pool-1-thread-4] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 27898507
#  INFO [pool-1-thread-5] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 22000
#  INFO [pool-1-thread-5] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 29213108
#  INFO [pool-1-thread-10] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 23000
#  INFO [pool-1-thread-10] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 30554895
#  INFO [pool-1-thread-16] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 24000
#  INFO [pool-1-thread-16] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 31908721
#  INFO [pool-1-thread-20] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 25000
#  INFO [pool-1-thread-20] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 33219348
#  INFO [pool-1-thread-18] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 26000
#  INFO [pool-1-thread-18] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 34569732
#  INFO [pool-1-thread-4] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 27000
#  INFO [pool-1-thread-4] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 35902410
#  INFO [pool-1-thread-13] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 28000
#  INFO [pool-1-thread-13] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 37265178
#  INFO [pool-1-thread-12] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 29000
#  INFO [pool-1-thread-12] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 38599605
#  INFO [pool-1-thread-18] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 30000
#  INFO [pool-1-thread-18] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 39920899
#  INFO [pool-1-thread-16] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 31000
#  INFO [pool-1-thread-16] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 41291527
#  INFO [pool-1-thread-8] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 32000
#  INFO [pool-1-thread-8] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 42638126
#  INFO [pool-1-thread-11] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 33000
#  INFO [pool-1-thread-11] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 43961261
#  INFO [pool-1-thread-6] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 34000
#  INFO [pool-1-thread-6] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 45278058
#  INFO [pool-1-thread-2] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 35000
#  INFO [pool-1-thread-2] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 46607958
#  INFO [pool-1-thread-13] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 36000
#  INFO [pool-1-thread-13] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 47933221
#  INFO [pool-1-thread-5] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 37000
#  INFO [pool-1-thread-5] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 49254944
#  INFO [pool-1-thread-3] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 38000
#  INFO [pool-1-thread-3] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 50629618
#  INFO [pool-1-thread-9] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 39000
#  INFO [pool-1-thread-9] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 51974535
#  INFO [pool-1-thread-2] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 40000
#  INFO [pool-1-thread-2] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 53308899
# DEBUG [main] (RequestAddCookies.java:123) - CookieSpec selected: default
# DEBUG [main] (RequestAuthCache.java:77) - Auth cache not set in the context
# DEBUG [main] (PoolingHttpClientConnectionManager.java:266) - Connection request: [route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:310) - Connection leased: [id: 0][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 1 of 2; total allocated: 1 of 20]
# DEBUG [main] (MainClientExec.java:234) - Opening connection {}->http://127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:139) - Connecting to /127.0.0.1:1808
# DEBUG [main] (LoggingManagedHttpClientConnection.java:96) - http-outgoing-0: Shutdown connection
# DEBUG [main] (ConnectionHolder.java:129) - Connection discarded
# DEBUG [main] (PoolingHttpClientConnectionManager.java:349) - Connection released: [id: 0][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
#  INFO [main] (Gensim.java:582) - Server is not yet running. Waiting 5 seconds. Trial 1 / 8
# DEBUG [main] (PoolingHttpClientConnectionManager.java:409) - Connection manager is shutting down
# DEBUG [main] (PoolingHttpClientConnectionManager.java:415) - Connection manager shut down
# DEBUG [main] (RequestAddCookies.java:123) - CookieSpec selected: default
# DEBUG [main] (RequestAuthCache.java:77) - Auth cache not set in the context
# DEBUG [main] (PoolingHttpClientConnectionManager.java:266) - Connection request: [route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:310) - Connection leased: [id: 1][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 1 of 2; total allocated: 1 of 20]
# DEBUG [main] (MainClientExec.java:234) - Opening connection {}->http://127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:139) - Connecting to /127.0.0.1:1808
# DEBUG [main] (LoggingManagedHttpClientConnection.java:96) - http-outgoing-1: Shutdown connection
# DEBUG [main] (ConnectionHolder.java:129) - Connection discarded
# DEBUG [main] (PoolingHttpClientConnectionManager.java:349) - Connection released: [id: 1][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
#  INFO [main] (Gensim.java:582) - Server is not yet running. Waiting 5 seconds. Trial 2 / 8
# DEBUG [main] (PoolingHttpClientConnectionManager.java:409) - Connection manager is shutting down
# DEBUG [main] (PoolingHttpClientConnectionManager.java:415) - Connection manager shut down
# DEBUG [main] (RequestAddCookies.java:123) - CookieSpec selected: default
# DEBUG [main] (RequestAuthCache.java:77) - Auth cache not set in the context
# DEBUG [main] (PoolingHttpClientConnectionManager.java:266) - Connection request: [route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:310) - Connection leased: [id: 2][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 1 of 2; total allocated: 1 of 20]
# DEBUG [main] (MainClientExec.java:234) - Opening connection {}->http://127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:139) - Connecting to /127.0.0.1:1808
# DEBUG [main] (LoggingManagedHttpClientConnection.java:96) - http-outgoing-2: Shutdown connection
# DEBUG [main] (ConnectionHolder.java:129) - Connection discarded
# DEBUG [main] (PoolingHttpClientConnectionManager.java:349) - Connection released: [id: 2][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
#  INFO [main] (Gensim.java:582) - Server is not yet running. Waiting 5 seconds. Trial 3 / 8
#  * Serving Flask app "python_server" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# DEBUG [main] (PoolingHttpClientConnectionManager.java:409) - Connection manager is shutting down
# DEBUG [main] (PoolingHttpClientConnectionManager.java:415) - Connection manager shut down
# DEBUG [main] (RequestAddCookies.java:123) - CookieSpec selected: default
# DEBUG [main] (RequestAuthCache.java:77) - Auth cache not set in the context
# DEBUG [main] (PoolingHttpClientConnectionManager.java:266) - Connection request: [route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:310) - Connection leased: [id: 3][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 1 of 2; total allocated: 1 of 20]
# DEBUG [main] (MainClientExec.java:234) - Opening connection {}->http://127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:139) - Connecting to /127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:146) - Connection established 127.0.0.1:59928<->127.0.0.1:1808
# DEBUG [main] (MainClientExec.java:255) - Executing request GET /melt_ml.html HTTP/1.1
# DEBUG [main] (MainClientExec.java:260) - Target auth state: UNCHALLENGED
# DEBUG [main] (MainClientExec.java:266) - Proxy auth state: UNCHALLENGED
# DEBUG [main] (LoggingManagedHttpClientConnection.java:133) - http-outgoing-3 >> GET /melt_ml.html HTTP/1.1
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-3 >> Host: 127.0.0.1:1808
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-3 >> Connection: Keep-Alive
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-3 >> User-Agent: Apache-HttpClient/4.5.10 (Java/11.0.8)
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-3 >> Accept-Encoding: gzip,deflate
# DEBUG [main] (Wire.java:73) - http-outgoing-3 >> "GET /melt_ml.html HTTP/1.1[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 >> "Host: 127.0.0.1:1808[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 >> "Connection: Keep-Alive[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 >> "User-Agent: Apache-HttpClient/4.5.10 (Java/11.0.8)[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 >> "Accept-Encoding: gzip,deflate[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 >> "[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 << "HTTP/1.0 200 OK[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 << "Content-Type: text/html; charset=utf-8[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 << "Content-Length: 49[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 << "Server: Werkzeug/1.0.1 Python/3.8.3[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 << "Date: Sat, 23 Jan 2021 09:55:11 GMT[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 << "[\r][\n]"
# DEBUG [main] (Wire.java:87) - http-outgoing-3 << "MELT ML Server running. Ready to accept requests."
# DEBUG [main] (LoggingManagedHttpClientConnection.java:122) - http-outgoing-3 << HTTP/1.0 200 OK
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-3 << Content-Type: text/html; charset=utf-8
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-3 << Content-Length: 49
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-3 << Server: Werkzeug/1.0.1 Python/3.8.3
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-3 << Date: Sat, 23 Jan 2021 09:55:11 GMT
#  INFO [main] (Gensim.java:578) - Server is running.
# DEBUG [main] (LoggingManagedHttpClientConnection.java:79) - http-outgoing-3: Close connection
# DEBUG [main] (ConnectionHolder.java:104) - Connection discarded
# DEBUG [main] (PoolingHttpClientConnectionManager.java:349) - Connection released: [id: 3][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# ERROR [main] (Gensim.java:413) - ERROR: The specified model path does not exist or is a directory.
# ERROR [main] (Gensim.java:414) - Provided file path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/evaluation_2/wn18_walks
# DEBUG [main] (RequestAddCookies.java:123) - CookieSpec selected: default
# DEBUG [main] (RequestAuthCache.java:77) - Auth cache not set in the context
# DEBUG [main] (PoolingHttpClientConnectionManager.java:266) - Connection request: [route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:310) - Connection leased: [id: 4][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 1 of 2; total allocated: 1 of 20]
# DEBUG [main] (MainClientExec.java:234) - Opening connection {}->http://127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:139) - Connecting to /127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:146) - Connection established 127.0.0.1:59930<->127.0.0.1:1808
# DEBUG [main] (MainClientExec.java:255) - Executing request GET /train-word2vec HTTP/1.1
# DEBUG [main] (MainClientExec.java:260) - Target auth state: UNCHALLENGED
# DEBUG [main] (MainClientExec.java:266) - Proxy auth state: UNCHALLENGED
# DEBUG [main] (LoggingManagedHttpClientConnection.java:133) - http-outgoing-4 >> GET /train-word2vec HTTP/1.1
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> vector_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/evaluation_2/wn18_walks/model.kv
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> model_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/evaluation_2/wn18_walks/model
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> file_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/evaluation_2/wn18_walks
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> vector_dimension: 200
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> number_of_threads: 20
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> window_size: 5
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> iterations: 5
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> negatives: 5
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> cbow_or_sg: sg
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> min_count: 1
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> sample: 0.0
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> epochs: 25
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> Host: 127.0.0.1:1808
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> Connection: Keep-Alive
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> User-Agent: Apache-HttpClient/4.5.10 (Java/11.0.8)
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> Accept-Encoding: gzip,deflate
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "GET /train-word2vec HTTP/1.1[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "vector_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/evaluation_2/wn18_walks/model.kv[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "model_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/evaluation_2/wn18_walks/model[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "file_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/evaluation_2/wn18_walks[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "vector_dimension: 200[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "number_of_threads: 20[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "window_size: 5[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "iterations: 5[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "negatives: 5[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "cbow_or_sg: sg[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "min_count: 1[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "sample: 0.0[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "epochs: 25[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "Host: 127.0.0.1:1808[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "Connection: Keep-Alive[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "User-Agent: Apache-HttpClient/4.5.10 (Java/11.0.8)[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "Accept-Encoding: gzip,deflate[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 << "HTTP/1.0 200 OK[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 << "Content-Type: text/html; charset=utf-8[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 << "Content-Length: 4[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 << "Server: Werkzeug/1.0.1 Python/3.8.3[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 << "Date: Sat, 23 Jan 2021 17:05:33 GMT[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 << "[\r][\n]"
# DEBUG [main] (Wire.java:87) - http-outgoing-4 << "True"
# DEBUG [main] (LoggingManagedHttpClientConnection.java:122) - http-outgoing-4 << HTTP/1.0 200 OK
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-4 << Content-Type: text/html; charset=utf-8
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-4 << Content-Length: 4
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-4 << Server: Werkzeug/1.0.1 Python/3.8.3
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-4 << Date: Sat, 23 Jan 2021 17:05:33 GMT
# DEBUG [main] (LoggingManagedHttpClientConnection.java:79) - http-outgoing-4: Close connection
# DEBUG [main] (ConnectionHolder.java:104) - Connection discarded
# DEBUG [main] (PoolingHttpClientConnectionManager.java:349) - Connection released: [id: 4][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (RequestAddCookies.java:123) - CookieSpec selected: default
# DEBUG [main] (RequestAuthCache.java:77) - Auth cache not set in the context
# DEBUG [main] (PoolingHttpClientConnectionManager.java:266) - Connection request: [route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:310) - Connection leased: [id: 5][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 1 of 2; total allocated: 1 of 20]
# DEBUG [main] (MainClientExec.java:234) - Opening connection {}->http://127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:139) - Connecting to /127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:146) - Connection established 127.0.0.1:33350<->127.0.0.1:1808
# DEBUG [main] (MainClientExec.java:255) - Executing request GET /write-model-as-text-file HTTP/1.1
# DEBUG [main] (MainClientExec.java:260) - Target auth state: UNCHALLENGED
# DEBUG [main] (MainClientExec.java:266) - Proxy auth state: UNCHALLENGED
# DEBUG [main] (LoggingManagedHttpClientConnection.java:133) - http-outgoing-5 >> GET /write-model-as-text-file HTTP/1.1
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> vector_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/evaluation_2/wn18_walks/model.kv
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> file_to_write: /work/jportisc/kbc_rdf2vec/strategy_grid_2/evaluation_2/wn18_walks/vectors.txt
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> Host: 127.0.0.1:1808
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> Connection: Keep-Alive
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> User-Agent: Apache-HttpClient/4.5.10 (Java/11.0.8)
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> Accept-Encoding: gzip,deflate
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "GET /write-model-as-text-file HTTP/1.1[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "vector_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/evaluation_2/wn18_walks/model.kv[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "file_to_write: /work/jportisc/kbc_rdf2vec/strategy_grid_2/evaluation_2/wn18_walks/vectors.txt[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "Host: 127.0.0.1:1808[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "Connection: Keep-Alive[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "User-Agent: Apache-HttpClient/4.5.10 (Java/11.0.8)[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "Accept-Encoding: gzip,deflate[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "[\r][\n]"
# Writing the vectors as text file.
# Processing 40961 vectors...
# Vectors processed: 10000 of 40961
# Vectors processed: 20000 of 40961
# Vectors processed: 30000 of 40961
# Vectors processed: 40000 of 40961
# DEBUG [main] (Wire.java:73) - http-outgoing-5 << "HTTP/1.0 200 OK[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 << "Content-Type: text/html; charset=utf-8[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 << "Content-Length: 4[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 << "Server: Werkzeug/1.0.1 Python/3.8.3[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 << "Date: Sat, 23 Jan 2021 17:06:30 GMT[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 << "[\r][\n]"
# DEBUG [main] (Wire.java:87) - http-outgoing-5 << "True"
# DEBUG [main] (LoggingManagedHttpClientConnection.java:122) - http-outgoing-5 << HTTP/1.0 200 OK
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-5 << Content-Type: text/html; charset=utf-8
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-5 << Content-Length: 4
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-5 << Server: Werkzeug/1.0.1 Python/3.8.3
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-5 << Date: Sat, 23 Jan 2021 17:06:30 GMT
# DEBUG [main] (LoggingManagedHttpClientConnection.java:79) - http-outgoing-5: Close connection
# DEBUG [main] (ConnectionHolder.java:104) - Connection discarded
# DEBUG [main] (PoolingHttpClientConnectionManager.java:349) - Connection released: [id: 5][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:409) - Connection manager is shutting down
# DEBUG [main] (PoolingHttpClientConnectionManager.java:415) - Connection manager shut down
#
# Total Time:
# Days: 0
# Hours: 7
# Minutes: 34
# Seconds: 54
#
#
# Walk Generation Time:
# Days: 0
# Hours: 0
# Minutes: 23
# Seconds: 20
#
#
# Training Time:
# Days: 0
# Hours: 7
# Minutes: 11
# Seconds: 34
#
#  INFO [Thread-0] (Gensim.java:605) - JVM shutdown detected - close python server if still open.
#  INFO [Thread-0] (Gensim.java:607) - Shutdown completed.

# %%
import os
import io

print(configuration_string)
fb15k_walk_path = os.path.join(work_dir, "fb15k_walks")
fb15k_nt_path = os.path.join(nt_dir, "FB15k.nt")

# !jrdf2vec -graph $fb15k_nt_path -numberOfWalks $number_of_walks -threads 20 -depth $depth -walkDirectory $fb15k_walk_path -trainingMode $training_mode -dimension $dimension -window $window -epochs $epochs

with io.open(os.path.join(fb15k_walk_path, "configuration.txt"), 'w+', encoding='utf8') as f:
    f.write(configuration_string)

# %% [markdown]
# ## Let's Check the Embeddings
#
# ```
# !jrdf2vec -analyzeVocab ./wn18_walks/model.kv ./WN18.nt &> wn_analysis.txt
# !jrdf2vec -analyzeVocab ./fb15k_walks/model.kv ./FB15k.nt &> fb_analysis.txt
#
# ```
# The reports are written to the specified files (`wn_analysis.txt`/`fb_analysis.txt`) as they can be quite long.
# You can find the reports in the walk directories.

# %%
import os

wn18_kv_path = os.path.join(wn18_walk_path, "model.kv")
wn18_analysis_path = os.path.join(wn18_walk_path, "wn_analysis.txt")

# !jrdf2vec -analyzeVocab $wn18_kv_path $wn_nt_path &> $wn18_analysis_path

# %%
import os

fb15k_kv_path = os.path.join(fb15k_walk_path, "model.kv")
fb15k_analysis = os.path.join(fb15k_walk_path, "fb_analysis.txt")

# !jrdf2vec -analyzeVocab $fb15k_kv_path $fb15k_nt_path &> $fb15k_analysis

# %% [markdown]
# ## Let's predict!
# We start by generating the files containing the predictions.

# %%
from kbc_rdf2vec.dataset import DataSet
from kbc_rdf2vec.prediction import PredictionFunctionEnum, PredictionFunction
from kbc_rdf2vec.rdf2vec_kbc import Rdf2vecKbc

import os


def generate_prediction_files() -> None:
    wn_vector_file = wn18_kv_path
    wn_nt_file = wn_nt_path
    fb15k_vector_file = fb15k_kv_path
    fb15k_nt_file = fb15k_nt_path

    # let's make a directory if it does not exist yet
    prediction_path = os.path.join(work_dir, "predictions")
    if not os.path.exists(prediction_path):
        os.makedirs(prediction_path)
    
    # ANN WN
    kbc = Rdf2vecKbc(
        model_path=wn_vector_file,
        data_set=DataSet.WN18,
        n=None,
        prediction_function=PredictionFunctionEnum.ANN,
        file_for_predicate_exclusion=wn_nt_file,
        is_reflexive_match_allowed=False,
    )
    kbc.predict(os.path.join(prediction_path, "wn_ann.txt"))

    # ANN FB
    kbc = Rdf2vecKbc(
        model_path=fb15k_vector_file,
        data_set=DataSet.FB15K,
        n=None,
        prediction_function=PredictionFunctionEnum.ANN,
        file_for_predicate_exclusion=fb15k_nt_file,
        is_reflexive_match_allowed=False,
    )
    kbc.predict(os.path.join(prediction_path, "fb15k_ann.txt"))
    

    # most similar WN
    kbc = Rdf2vecKbc(
        model_path=wn_vector_file,
        n=None,
        data_set=DataSet.WN18,
        file_for_predicate_exclusion=wn_nt_file,
        is_reflexive_match_allowed=False,
        prediction_function=PredictionFunctionEnum.MOST_SIMILAR,
    )
    kbc.predict(os.path.join(prediction_path, "wn_most_similar.txt"))
    
    # most similar FB
    kbc = Rdf2vecKbc(
        model_path=fb15k_vector_file,
        n=None,
        data_set=DataSet.FB15K,
        file_for_predicate_exclusion=fb15k_nt_file,
        is_reflexive_match_allowed=False,
        prediction_function=PredictionFunctionEnum.MOST_SIMILAR,
    )
    kbc.predict(os.path.join(prediction_path, "fb15k_most_similar.txt"))
    
    # avg most similar WN
    kbc = Rdf2vecKbc(
        model_path=wn_vector_file,
        n=None,
        data_set=DataSet.WN18,
        file_for_predicate_exclusion=wn_nt_file,
        is_reflexive_match_allowed=False,
        prediction_function=PredictionFunctionEnum.PREDICATE_AVERAGING_MOST_SIMILAR,
    )
    kbc.predict(os.path.join(prediction_path, "wn_averaged_most_similar.txt"))

    # avg most similar FB
    kbc = Rdf2vecKbc(
        model_path=fb15k_vector_file,
        n=None,
        data_set=DataSet.FB15K,
        file_for_predicate_exclusion=fb15k_nt_file,
        is_reflexive_match_allowed=False,
        prediction_function=PredictionFunctionEnum.PREDICATE_AVERAGING_MOST_SIMILAR,
    )
    kbc.predict(os.path.join(prediction_path, "fb15k_averaged_most_similar.txt")) 
    
    # addition WN
    kbc = Rdf2vecKbc(
        model_path=wn_vector_file,
        n=None,
        data_set=DataSet.WN18,
        file_for_predicate_exclusion=wn_nt_file,
        is_reflexive_match_allowed=False,
        prediction_function=PredictionFunctionEnum.ADDITION,
    )
    kbc.predict(os.path.join(prediction_path, "wn_addition.txt"))

    # addition FB
    kbc = Rdf2vecKbc(
        model_path=fb15k_vector_file,
        n=None,
        data_set=DataSet.FB15K,
        file_for_predicate_exclusion=fb15k_nt_file,
        is_reflexive_match_allowed=False,
        prediction_function=PredictionFunctionEnum.ADDITION,
    )
    kbc.predict(os.path.join(prediction_path, "fb15k_addition.txt"))
    
    # addition FB with reflexive matches allowed
    kbc = Rdf2vecKbc(
        model_path=fb15k_vector_file,
        n=None,
        data_set=DataSet.FB15K,
        file_for_predicate_exclusion=fb15k_nt_file,
        is_reflexive_match_allowed=True,
        prediction_function=PredictionFunctionEnum.ADDITION,
    )
    kbc.predict(os.path.join(prediction_path, "fb15k_reflexive_addition.txt"))
    
    # avg addition WN
    kbc = Rdf2vecKbc(
        model_path=wn_vector_file,
        n=None,
        data_set=DataSet.WN18,
        file_for_predicate_exclusion=wn_nt_file,
        is_reflexive_match_allowed=False,
        prediction_function=PredictionFunctionEnum.PREDICATE_AVERAGING_ADDITION,
    )
    kbc.predict(os.path.join(prediction_path, "wn_averaged_addition.txt"))

    # avg addition FB
    kbc = Rdf2vecKbc(
        model_path=fb15k_vector_file,
        n=None,
        data_set=DataSet.FB15K,
        file_for_predicate_exclusion=fb15k_nt_file,
        is_reflexive_match_allowed=False,
        prediction_function=PredictionFunctionEnum.PREDICATE_AVERAGING_ADDITION,
    )
    kbc.predict(os.path.join(prediction_path, "fb15k_averaged_addition.txt"))
    
    # avg addition FB with reflexive matches allowed
    kbc = Rdf2vecKbc(
        model_path=fb15k_vector_file,
        n=None,
        data_set=DataSet.FB15K,
        file_for_predicate_exclusion=fb15k_nt_file,
        is_reflexive_match_allowed=True,
        prediction_function=PredictionFunctionEnum.PREDICATE_AVERAGING_ADDITION,
    )
    kbc.predict(os.path.join(prediction_path, "fb15k_reflexive_averaged_addition.txt"))
    

generate_prediction_files()

# %% [markdown]
# ## Let's evaluate!
# Now we just evaluate the files that we have.

# %%
from kbc_evaluation.evaluator import Evaluator, EvaluatorResult 
from kbc_rdf2vec.dataset import DataSet
from typing import List, Tuple
import os
import pickle


work_dir = "/work/jportisc/kbc_rdf2vec/strategy_grid_2/evaluation_2"
prediction_path = os.path.join(work_dir, "predictions")

def evaluate_files() -> List[Tuple[str, EvaluatorResult]]:
    
    result_map = {}
    
    # Let's make a directory for the evaluation
    evaluation_path = os.path.join(work_dir, "evaluation")
    if not os.path.exists(evaluation_path):
        os.makedirs(evaluation_path)
    
    #--------------------
    # evaluation of WN 18
    #--------------------
    
    file_to_be_written=os.path.join(evaluation_path, "wn_ann_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "wn_ann.txt"),
        data_set=DataSet.WN18,
        n=10,
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["ANN"] = [results]
    
    
    file_to_be_written=os.path.join(evaluation_path, "wn_most_similar_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "wn_most_similar.txt"),
        data_set=DataSet.WN18,
        n=10,
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H, L)"] = [results]

    
    file_to_be_written=os.path.join(evaluation_path, "wn_averaged_most_similar_result.txt")
    Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "wn_averaged_most_similar.txt"),
        data_set=DataSet.WN18,
        n=10,
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H, AVG(T-H))"] = [results]

    
    file_to_be_written=os.path.join(evaluation_path, "wn_addition_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "wn_addition.txt"),
        data_set=DataSet.WN18,
        n=10
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H + L)"] = [results]
    
    
    file_to_be_written=os.path.join(evaluation_path, "wn_averaged_addition_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "wn_averaged_addition.txt"),
        data_set=DataSet.WN18,
        n = 10
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H + AVG(T-H))"] = [results]
    
    
    #--------------------
    # evaluation of fb15k
    #--------------------    

    file_to_be_written=os.path.join(evaluation_path, "fb15k_ann_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "fb15k_ann.txt"),
        data_set=DataSet.FB15K,
        n=10,
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["ANN"].append(results)

    
    file_to_be_written=os.path.join(evaluation_path, "fb15k_most_similar_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "fb15k_most_similar.txt"),
        data_set=DataSet.FB15K,
        n=10
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H, L)"].append(results)

    
    file_to_be_written=os.path.join(evaluation_path, "fb15k_averaged_most_similar_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "fb15k_averaged_most_similar.txt"),
        data_set=DataSet.FB15K,
        n=10,
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H, AVG(T-H))"].append(results)

    
    file_to_be_written=os.path.join(evaluation_path, "fb15k_addition_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "fb15k_addition.txt"),
        data_set=DataSet.FB15K,
        n=10
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H + L)"].append(results)
    

    file_to_be_written=os.path.join(evaluation_path, "fb15k_averaged_addition_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "fb15k_averaged_addition.txt"),
        data_set=DataSet.FB15K,
        n=10
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H + AVG(T-H))"].append(results)
    

    file_to_be_written=os.path.join(evaluation_path, "fb15k_reflexive_addition_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "fb15k_reflexive_addition.txt"),
        data_set=DataSet.FB15K,
        n=10
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H + L) reflexive"] = [None, results]
    

    file_to_be_written=os.path.join(evaluation_path, "fb15k_reflexive_averaged_addition_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "fb15k_reflexive_averaged_addition.txt"),
        data_set=DataSet.FB15K,
        n=10
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H + AVG(T-H)) reflexive"] = [None, results]
    
    # The result map is expensive to calculate, so let's persist it.
    with open(os.path.join(prediction_path, "result_map.pickle"), 'wb') as f:
        pickle.dump(result_map, f, pickle.HIGHEST_PROTOCOL)
    
    return result_map

    
result_map = evaluate_files()
# Out:
# Reading provided file...
# 2021-02-01 23:09:47,804 - root - INFO - Hits@10 Heads: 3342
# 2021-02-01 23:09:47,806 - root - INFO - Hits@10 Tails: 1626
# 2021-02-01 23:09:47,807 - root - INFO - Hits@10 Total: 4968
# 2021-02-01 23:09:48,255 - kbc_evaluation.evaluator - INFO - Calculating Mean Rank
# 2021-02-01 23:09:48,397 - root - INFO - Mean Head Rank: 108.275 (0 ignored lines)
# Mean Reciprocal Head Rank: 0.4350056284916208 (0 ignored lines)
# 2021-02-01 23:09:48,399 - root - INFO - Mean Tail Rank: 598.5542 (0 ignored lines)
# Mean Reciprocal Tail Rank: 0.20552996005991991 (0 ignored lines)
# 2021-02-01 23:09:48,400 - root - INFO - Mean rank: 353.4146; rounded: 353
# 2021-02-01 23:09:48,401 - root - INFO - Mean reciprocal rank: 0.32026779427577035
# Reading provided file...
# 2021-02-01 23:10:11,344 - kbc_evaluation.dataset - INFO - Apply Filtering
# 2021-02-01 23:10:11,346 - kbc_evaluation.dataset - INFO - Read Training File
# 2021-02-01 23:10:34,440 - kbc_evaluation.dataset - INFO - Read Validation File
# 2021-02-01 23:10:34,473 - kbc_evaluation.dataset - INFO - Read Test File
# 100%|██████████| 5000/5000 [00:04<00:00, 1145.11it/s]
# 2021-02-01 23:10:46,335 - root - INFO - Hits@10 Heads: 3807
# 2021-02-01 23:10:46,341 - root - INFO - Hits@10 Tails: 1736
# 2021-02-01 23:10:46,342 - root - INFO - Hits@10 Total: 5543
# 2021-02-01 23:10:46,343 - kbc_evaluation.evaluator - INFO - Calculating Mean Rank
# 2021-02-01 23:10:46,473 - root - INFO - Mean Head Rank: 96.6576 (0 ignored lines)
# Mean Reciprocal Head Rank: 0.539795918202685 (0 ignored lines)
# 2021-02-01 23:10:46,475 - root - INFO - Mean Tail Rank: 586.7884 (0 ignored lines)
# Mean Reciprocal Tail Rank: 0.22217265009092663 (0 ignored lines)
# 2021-02-01 23:10:46,475 - root - INFO - Mean rank: 341.723; rounded: 342
# 2021-02-01 23:10:46,476 - root - INFO - Mean reciprocal rank: 0.38098428414680585
# 2021-02-01 23:10:46,780 - kbc_evaluation.evaluator - INFO -
# This is the evaluation of file /work/jportisc/kbc_rdf2vec/strategy_grid_2/evaluation_2/predictions/wn_ann.txt
#
# Non-filtered Results
# --------------------
# Test set size: 5000
# Hits at 10 (Heads): 3342
# Hits at 10 (Tails): 1626
# Hits at 10 (All): 4968
# Relative Hits at 10: 0.4968
# Mean rank (Heads): 108
# Mean rank (Tails): 599
# Mean rank (All): 353
# Mean reciprocal rank (Heads): 0.4350056284916208
# Mean reciprocal rank (Tails): 0.20552996005991991
# Mean reciprocal rank (All): 0.32026779427577035
#
#
# Filtered Results
# ----------------
# Test set size: 5000
# Hits at 10 (Heads): 3807
# Hits at 10 (Tails): 1736
# Hits at 10 (All): 5543
# Relative Hits at 10: 0.5543
# Mean rank (Heads): 97
# Mean rank (Tails): 587
# Mean rank (All): 342
# Mean reciprocal rank (Heads): 0.539795918202685
# Mean reciprocal rank (Tails): 0.22217265009092663
# Mean reciprocal rank (All): 0.38098428414680585
#
# Reading provided file...
# 2021-02-01 23:11:07,371 - root - INFO - Hits@10 Heads: 3125
# 2021-02-01 23:11:07,373 - root - INFO - Hits@10 Tails: 2955
# 2021-02-01 23:11:07,374 - root - INFO - Hits@10 Total: 6080
# 2021-02-01 23:11:07,440 - kbc_evaluation.evaluator - INFO - Calculating Mean Rank
# 2021-02-01 23:11:07,514 - root - INFO - Mean Head Rank: 173.8068 (0 ignored lines)
# Mean Reciprocal Head Rank: 0.39531165394706724 (0 ignored lines)
# 2021-02-01 23:11:07,516 - root - INFO - Mean Tail Rank: 186.1328 (0 ignored lines)
# Mean Reciprocal Tail Rank: 0.3736903894443348 (0 ignored lines)
# 2021-02-01 23:11:07,517 - root - INFO - Mean rank: 179.96980000000002; rounded: 180
# 2021-02-01 23:11:07,518 - root - INFO - Mean reciprocal rank: 0.384501021695701
# Reading provided file...
# 2021-02-01 23:11:30,197 - kbc_evaluation.dataset - INFO - Apply Filtering
# 2021-02-01 23:11:30,198 - kbc_evaluation.dataset - INFO - Read Training File
# 2021-02-01 23:11:46,249 - kbc_evaluation.dataset - INFO - Read Validation File
# 2021-02-01 23:11:51,278 - kbc_evaluation.dataset - INFO - Read Test File
# 100%|██████████| 5000/5000 [00:03<00:00, 1312.26it/s]
# 2021-02-01 23:12:02,387 - root - INFO - Hits@10 Heads: 3405
# 2021-02-01 23:12:02,394 - root - INFO - Hits@10 Tails: 3128
# 2021-02-01 23:12:02,395 - root - INFO - Hits@10 Total: 6533
# 2021-02-01 23:12:02,396 - kbc_evaluation.evaluator - INFO - Calculating Mean Rank
# 2021-02-01 23:12:02,474 - root - INFO - Mean Head Rank: 162.9054 (0 ignored lines)
# Mean Reciprocal Head Rank: 0.45837424678259303 (0 ignored lines)
# 2021-02-01 23:12:02,476 - root - INFO - Mean Tail Rank: 173.7438 (0 ignored lines)
# Mean Reciprocal Tail Rank: 0.40614056356471184 (0 ignored lines)
# 2021-02-01 23:12:02,477 - root - INFO - Mean rank: 168.32459999999998; rounded: 168
# 2021-02-01 23:12:02,478 - root - INFO - Mean reciprocal rank: 0.4322574051736524
# 2021-02-01 23:12:02,772 - kbc_evaluation.evaluator - INFO -
# This is the evaluation of file /work/jportisc/kbc_rdf2vec/strategy_grid_2/evaluation_2/predictions/wn_most_similar.txt
#
# Non-filtered Results
# --------------------
# Test set size: 5000
# Hits at 10 (Heads): 3125
# Hits at 10 (Tails): 2955
# Hits at 10 (All): 6080
# Relative Hits at 10: 0.608
# Mean rank (Heads): 174
# Mean rank (Tails): 186
# Mean rank (All): 180
# Mean reciprocal rank (Heads): 0.39531165394706724
# Mean reciprocal rank (Tails): 0.3736903894443348
# Mean reciprocal rank (All): 0.384501021695701
#
#
# Filtered Results
# ----------------
# Test set size: 5000
# Hits at 10 (Heads): 3405
# Hits at 10 (Tails): 3128
# Hits at 10 (All): 6533
# Relative Hits at 10: 0.6533
# Mean rank (Heads): 163
# Mean rank (Tails): 174
# Mean rank (All): 168
# Mean reciprocal rank (Heads): 0.45837424678259303
# Mean reciprocal rank (Tails): 0.40614056356471184
# Mean reciprocal rank (All): 0.4322574051736524
#
# Reading provided file...
# 2021-02-01 23:12:58,295 - root - INFO - Hits@10 Heads: 2128
# 2021-02-01 23:12:58,297 - root - INFO - Hits@10 Tails: 1832
# 2021-02-01 23:12:58,298 - root - INFO - Hits@10 Total: 3960
# 2021-02-01 23:13:01,452 - kbc_evaluation.evaluator - INFO - Calculating Mean Rank
# 2021-02-01 23:13:01,574 - root - INFO - Mean Head Rank: 302.7476 (0 ignored lines)
# Mean Reciprocal Head Rank: 0.1708533170846972 (0 ignored lines)
# 2021-02-01 23:13:01,575 - root - INFO - Mean Tail Rank: 279.0686 (0 ignored lines)
# Mean Reciprocal Tail Rank: 0.1274944732458705 (0 ignored lines)
# 2021-02-01 23:13:01,576 - root - INFO - Mean rank: 290.9081; rounded: 291
# 2021-02-01 23:13:01,578 - root - INFO - Mean reciprocal rank: 0.14917389516528384
# Reading provided file...
# 2021-02-01 23:14:01,946 - kbc_evaluation.dataset - INFO - Apply Filtering
# 2021-02-01 23:14:01,948 - kbc_evaluation.dataset - INFO - Read Training File
# 2021-02-01 23:15:09,445 - kbc_evaluation.dataset - INFO - Read Validation File
# 2021-02-01 23:15:09,468 - kbc_evaluation.dataset - INFO - Read Test File
# 100%|██████████| 5000/5000 [00:04<00:00, 1140.44it/s]
# 2021-02-01 23:16:11,444 - root - INFO - Hits@10 Heads: 2596
# 2021-02-01 23:16:11,446 - root - INFO - Hits@10 Tails: 2221
# 2021-02-01 23:16:11,448 - root - INFO - Hits@10 Total: 4817
# 2021-02-01 23:16:11,449 - kbc_evaluation.evaluator - INFO - Calculating Mean Rank
# 2021-02-01 23:16:11,609 - root - INFO - Mean Head Rank: 289.9074 (0 ignored lines)
# Mean Reciprocal Head Rank: 0.24583635456695294 (0 ignored lines)
# 2021-02-01 23:16:11,611 - root - INFO - Mean Tail Rank: 264.571 (0 ignored lines)
# Mean Reciprocal Tail Rank: 0.17704666437106456 (0 ignored lines)
# 2021-02-01 23:16:11,612 - root - INFO - Mean rank: 277.2392; rounded: 277
# 2021-02-01 23:16:11,613 - root - INFO - Mean reciprocal rank: 0.21144150946900875
# 2021-02-01 23:16:12,137 - kbc_evaluation.evaluator - INFO -
# This is the evaluation of file /work/jportisc/kbc_rdf2vec/strategy_grid_2/evaluation_2/predictions/wn_most_similar.txt
#
# Non-filtered Results
# --------------------
# Test set size: 5000
# Hits at 10 (Heads): 3125
# Hits at 10 (Tails): 2955
# Hits at 10 (All): 6080
# Relative Hits at 10: 0.608
# Mean rank (Heads): 174
# Mean rank (Tails): 186
# Mean rank (All): 180
# Mean reciprocal rank (Heads): 0.39531165394706724
# Mean reciprocal rank (Tails): 0.3736903894443348
# Mean reciprocal rank (All): 0.384501021695701
#
#
# Filtered Results
# ----------------
# Test set size: 5000
# Hits at 10 (Heads): 3405
# Hits at 10 (Tails): 3128
# Hits at 10 (All): 6533
# Relative Hits at 10: 0.6533
# Mean rank (Heads): 163
# Mean rank (Tails): 174
# Mean rank (All): 168
# Mean reciprocal rank (Heads): 0.45837424678259303
# Mean reciprocal rank (Tails): 0.40614056356471184
# Mean reciprocal rank (All): 0.4322574051736524
#
# Reading provided file...
# 2021-02-01 23:16:33,686 - root - INFO - Hits@10 Heads: 3116
# 2021-02-01 23:16:33,689 - root - INFO - Hits@10 Tails: 3231
# 2021-02-01 23:16:33,690 - root - INFO - Hits@10 Total: 6347
# 2021-02-01 23:16:34,336 - kbc_evaluation.evaluator - INFO - Calculating Mean Rank
# 2021-02-01 23:16:34,411 - root - INFO - Mean Head Rank: 191.9808 (0 ignored lines)
# Mean Reciprocal Head Rank: 0.4055827720914533 (0 ignored lines)
# 2021-02-01 23:16:34,412 - root - INFO - Mean Tail Rank: 141.1032 (0 ignored lines)
# Mean Reciprocal Tail Rank: 0.41304120025581925 (0 ignored lines)
# 2021-02-01 23:16:34,413 - root - INFO - Mean rank: 166.54199999999997; rounded: 167
# 2021-02-01 23:16:34,414 - root - INFO - Mean reciprocal rank: 0.4093119861736363
# Reading provided file...
# 2021-02-01 23:16:56,079 - kbc_evaluation.dataset - INFO - Apply Filtering
# 2021-02-01 23:16:56,085 - kbc_evaluation.dataset - INFO - Read Training File
# 2021-02-01 23:17:13,977 - kbc_evaluation.dataset - INFO - Read Validation File
# 2021-02-01 23:17:13,996 - kbc_evaluation.dataset - INFO - Read Test File
# 100%|██████████| 5000/5000 [00:10<00:00, 460.78it/s]
# 2021-02-01 23:17:32,299 - root - INFO - Hits@10 Heads: 3484
# 2021-02-01 23:17:32,306 - root - INFO - Hits@10 Tails: 3494
# 2021-02-01 23:17:32,306 - root - INFO - Hits@10 Total: 6978
# 2021-02-01 23:17:32,307 - kbc_evaluation.evaluator - INFO - Calculating Mean Rank
# 2021-02-01 23:17:32,377 - root - INFO - Mean Head Rank: 179.9244 (0 ignored lines)
# Mean Reciprocal Head Rank: 0.46469083831065544 (0 ignored lines)
# 2021-02-01 23:17:32,378 - root - INFO - Mean Tail Rank: 128.4112 (0 ignored lines)
# Mean Reciprocal Tail Rank: 0.4578524675127124 (0 ignored lines)
# 2021-02-01 23:17:32,379 - root - INFO - Mean rank: 154.1678; rounded: 154
# 2021-02-01 23:17:32,380 - root - INFO - Mean reciprocal rank: 0.4612716529116839
# 2021-02-01 23:17:32,593 - kbc_evaluation.evaluator - INFO -
# This is the evaluation of file /work/jportisc/kbc_rdf2vec/strategy_grid_2/evaluation_2/predictions/wn_addition.txt
#
# Non-filtered Results
# --------------------
# Test set size: 5000
# Hits at 10 (Heads): 3116
# Hits at 10 (Tails): 3231
# Hits at 10 (All): 6347
# Relative Hits at 10: 0.6347
# Mean rank (Heads): 192
# Mean rank (Tails): 141
# Mean rank (All): 167
# Mean reciprocal rank (Heads): 0.4055827720914533
# Mean reciprocal rank (Tails): 0.41304120025581925
# Mean reciprocal rank (All): 0.4093119861736363
#
#
# Filtered Results
# ----------------
# Test set size: 5000
# Hits at 10 (Heads): 3484
# Hits at 10 (Tails): 3494
# Hits at 10 (All): 6978
# Relative Hits at 10: 0.6978
# Mean rank (Heads): 180
# Mean rank (Tails): 128
# Mean rank (All): 154
# Mean reciprocal rank (Heads): 0.46469083831065544
# Mean reciprocal rank (Tails): 0.4578524675127124
# Mean reciprocal rank (All): 0.4612716529116839
#
# Reading provided file...
# 2021-02-01 23:17:53,255 - root - INFO - Hits@10 Heads: 3118
# 2021-02-01 23:17:53,257 - root - INFO - Hits@10 Tails: 3321
# 2021-02-01 23:17:53,258 - root - INFO - Hits@10 Total: 6439
# 2021-02-01 23:17:53,325 - kbc_evaluation.evaluator - INFO - Calculating Mean Rank
# 2021-02-01 23:17:53,388 - root - INFO - Mean Head Rank: 161.0148 (0 ignored lines)
# Mean Reciprocal Head Rank: 0.411389151146705 (0 ignored lines)
# 2021-02-01 23:17:53,389 - root - INFO - Mean Tail Rank: 132.8968 (0 ignored lines)
# Mean Reciprocal Tail Rank: 0.42355479267524204 (0 ignored lines)
# 2021-02-01 23:17:53,390 - root - INFO - Mean rank: 146.9558; rounded: 147
# 2021-02-01 23:17:53,391 - root - INFO - Mean reciprocal rank: 0.4174719719109735
# Reading provided file...
# 2021-02-01 23:18:14,739 - kbc_evaluation.dataset - INFO - Apply Filtering
# 2021-02-01 23:18:14,740 - kbc_evaluation.dataset - INFO - Read Training File
# 2021-02-01 23:18:30,256 - kbc_evaluation.dataset - INFO - Read Validation File
# 2021-02-01 23:18:30,275 - kbc_evaluation.dataset - INFO - Read Test File
# 100%|██████████| 5000/5000 [00:03<00:00, 1464.83it/s]
# 2021-02-01 23:18:45,227 - root - INFO - Hits@10 Heads: 3491
# 2021-02-01 23:18:45,234 - root - INFO - Hits@10 Tails: 3642
# 2021-02-01 23:18:45,234 - root - INFO - Hits@10 Total: 7133
# 2021-02-01 23:18:45,235 - kbc_evaluation.evaluator - INFO - Calculating Mean Rank
# 2021-02-01 23:18:45,292 - root - INFO - Mean Head Rank: 148.9018 (0 ignored lines)
# Mean Reciprocal Head Rank: 0.4806967882261843 (0 ignored lines)
# 2021-02-01 23:18:45,293 - root - INFO - Mean Tail Rank: 120.345 (0 ignored lines)
# Mean Reciprocal Tail Rank: 0.4765626973622755 (0 ignored lines)
# 2021-02-01 23:18:45,294 - root - INFO - Mean rank: 134.6234; rounded: 135
# 2021-02-01 23:18:45,295 - root - INFO - Mean reciprocal rank: 0.4786297427942299
# 2021-02-01 23:18:45,501 - kbc_evaluation.evaluator - INFO -
# This is the evaluation of file /work/jportisc/kbc_rdf2vec/strategy_grid_2/evaluation_2/predictions/wn_averaged_addition.txt
#
# Non-filtered Results
# --------------------
# Test set size: 5000
# Hits at 10 (Heads): 3118
# Hits at 10 (Tails): 3321
# Hits at 10 (All): 6439
# Relative Hits at 10: 0.6439
# Mean rank (Heads): 161
# Mean rank (Tails): 133
# Mean rank (All): 147
# Mean reciprocal rank (Heads): 0.411389151146705
# Mean reciprocal rank (Tails): 0.42355479267524204
# Mean reciprocal rank (All): 0.4174719719109735
#
#
# Filtered Results
# ----------------
# Test set size: 5000
# Hits at 10 (Heads): 3491
# Hits at 10 (Tails): 3642
# Hits at 10 (All): 7133
# Relative Hits at 10: 0.7133
# Mean rank (Heads): 149
# Mean rank (Tails): 120
# Mean rank (All): 135
# Mean reciprocal rank (Heads): 0.4806967882261843
# Mean reciprocal rank (Tails): 0.4765626973622755
# Mean reciprocal rank (All): 0.4786297427942299
#
# Reading provided file...
# 2021-02-01 23:20:14,913 - root - INFO - Hits@10 Heads: 25975
# 2021-02-01 23:20:14,915 - root - INFO - Hits@10 Tails: 14485
# 2021-02-01 23:20:14,915 - root - INFO - Hits@10 Total: 40460
# 2021-02-01 23:20:15,174 - kbc_evaluation.evaluator - INFO - Calculating Mean Rank
# 2021-02-01 23:20:15,178 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01q2sk Triple: ('/m/01q2sk', '/education/educational_institution_campus/educational_institution', '/m/01q2sk')
# 2021-02-01 23:20:15,179 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01q2sk Triple: ('/m/01q2sk', '/education/educational_institution_campus/educational_institution', '/m/01q2sk')
# 2021-02-01 23:20:15,182 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/05xb7q Triple: ('/m/05xb7q', '/education/educational_institution/campuses', '/m/05xb7q')
# 2021-02-01 23:20:15,184 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/05xb7q Triple: ('/m/05xb7q', '/education/educational_institution/campuses', '/m/05xb7q')
# 2021-02-01 23:20:15,190 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0288zy Triple: ('/m/0288zy', '/education/educational_institution/campuses', '/m/0288zy')
# 2021-02-01 23:20:15,191 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0288zy Triple: ('/m/0288zy', '/education/educational_institution/campuses', '/m/0288zy')
# 2021-02-01 23:20:15,198 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0q8p8 Triple: ('/m/0q8p8', '/location/hud_county_place/place', '/m/0q8p8')
# 2021-02-01 23:20:15,199 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0q8p8 Triple: ('/m/0q8p8', '/location/hud_county_place/place', '/m/0q8p8')
# 2021-02-01 23:20:15,208 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0f04v Triple: ('/m/0f04v', '/location/neighborhood/neighborhood_of', '/m/0f04v')
# 2021-02-01 23:20:15,210 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0f04v Triple: ('/m/0f04v', '/location/neighborhood/neighborhood_of', '/m/0f04v')
# 2021-02-01 23:20:15,218 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/04wlz2 Triple: ('/m/04wlz2', '/education/educational_institution/campuses', '/m/04wlz2')
# 2021-02-01 23:20:15,220 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/04wlz2 Triple: ('/m/04wlz2', '/education/educational_institution/campuses', '/m/04wlz2')
# 2021-02-01 23:20:15,227 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/065r8g Triple: ('/m/065r8g', '/education/educational_institution_campus/educational_institution', '/m/065r8g')
# 2021-02-01 23:20:15,228 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/065r8g Triple: ('/m/065r8g', '/education/educational_institution_campus/educational_institution', '/m/065r8g')
# 2021-02-01 23:20:15,232 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01t38b Triple: ('/m/01t38b', '/education/educational_institution/campuses', '/m/01t38b')
# 2021-02-01 23:20:15,236 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01t38b Triple: ('/m/01t38b', '/education/educational_institution/campuses', '/m/01t38b')
# 2021-02-01 23:20:15,252 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/060bp Triple: ('/m/060bp', '/government/government_office_category/offices', '/m/060bp')
# 2021-02-01 23:20:15,253 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/060bp Triple: ('/m/060bp', '/government/government_office_category/offices', '/m/060bp')
# 2021-02-01 23:20:15,255 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0jpn8 Triple: ('/m/0jpn8', '/education/educational_institution_campus/educational_institution', '/m/0jpn8')
# 2021-02-01 23:20:15,256 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0jpn8 Triple: ('/m/0jpn8', '/education/educational_institution_campus/educational_institution', '/m/0jpn8')
# 2021-02-01 23:20:15,283 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/027xq5 Triple: ('/m/027xq5', '/education/educational_institution/campuses', '/m/027xq5')
# 2021-02-01 23:20:15,284 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/027xq5 Triple: ('/m/027xq5', '/education/educational_institution/campuses', '/m/027xq5')
# 2021-02-01 23:20:15,287 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/04f_d Triple: ('/m/04f_d', '/location/hud_county_place/place', '/m/04f_d')
# 2021-02-01 23:20:15,288 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/04f_d Triple: ('/m/04f_d', '/location/hud_county_place/place', '/m/04f_d')
# 2021-02-01 23:20:15,298 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01bk1y Triple: ('/m/01bk1y', '/education/educational_institution_campus/educational_institution', '/m/01bk1y')
# 2021-02-01 23:20:15,299 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01bk1y Triple: ('/m/01bk1y', '/education/educational_institution_campus/educational_institution', '/m/01bk1y')
# 2021-02-01 23:20:15,300 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/058cm Triple: ('/m/058cm', '/location/hud_county_place/place', '/m/058cm')
# 2021-02-01 23:20:15,301 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/058cm Triple: ('/m/058cm', '/location/hud_county_place/place', '/m/058cm')
# 2021-02-01 23:20:15,306 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01hb1t Triple: ('/m/01hb1t', '/education/educational_institution_campus/educational_institution', '/m/01hb1t')
# 2021-02-01 23:20:15,309 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01hb1t Triple: ('/m/01hb1t', '/education/educational_institution_campus/educational_institution', '/m/01hb1t')
# 2021-02-01 23:20:15,312 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0mnsf Triple: ('/m/0mnsf', '/location/hud_county_place/place', '/m/0mnsf')
# 2021-02-01 23:20:15,314 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0mnsf Triple: ('/m/0mnsf', '/location/hud_county_place/place', '/m/0mnsf')
# 2021-02-01 23:20:15,325 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0qlrh Triple: ('/m/0qlrh', '/location/hud_county_place/place', '/m/0qlrh')
# 2021-02-01 23:20:15,327 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0qlrh Triple: ('/m/0qlrh', '/location/hud_county_place/place', '/m/0qlrh')
# 2021-02-01 23:20:15,333 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01ljpm Triple: ('/m/01ljpm', '/education/educational_institution/campuses', '/m/01ljpm')
# 2021-02-01 23:20:15,335 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01ljpm Triple: ('/m/01ljpm', '/education/educational_institution/campuses', '/m/01ljpm')
# 2021-02-01 23:20:15,337 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/02frhbc Triple: ('/m/02frhbc', '/location/hud_county_place/place', '/m/02frhbc')
# 2021-02-01 23:20:15,338 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/02frhbc Triple: ('/m/02frhbc', '/location/hud_county_place/place', '/m/02frhbc')
# 2021-02-01 23:20:15,352 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/02t4yc Triple: ('/m/02t4yc', '/education/educational_institution_campus/educational_institution', '/m/02t4yc')
# 2021-02-01 23:20:15,354 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/02t4yc Triple: ('/m/02t4yc', '/education/educational_institution_campus/educational_institution', '/m/02t4yc')
# 2021-02-01 23:20:15,380 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/03x23q Triple: ('/m/03x23q', '/education/educational_institution_campus/educational_institution', '/m/03x23q')
# 2021-02-01 23:20:15,382 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/03x23q Triple: ('/m/03x23q', '/education/educational_institution_campus/educational_institution', '/m/03x23q')
# 2021-02-01 23:20:15,384 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0235l Triple: ('/m/0235l', '/location/us_county/hud_county_place', '/m/0235l')
# 2021-02-01 23:20:15,385 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0235l Triple: ('/m/0235l', '/location/us_county/hud_county_place', '/m/0235l')
# 2021-02-01 23:20:15,403 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0mnwd Triple: ('/m/0mnwd', '/location/hud_county_place/county', '/m/0mnwd')
# 2021-02-01 23:20:15,404 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0mnwd Triple: ('/m/0mnwd', '/location/hud_county_place/county', '/m/0mnwd')
# 2021-02-01 23:20:15,408 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01s753 Triple: ('/m/01s753', '/education/educational_institution_campus/educational_institution', '/m/01s753')
# 2021-02-01 23:20:15,408 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01s753 Triple: ('/m/01s753', '/education/educational_institution_campus/educational_institution', '/m/01s753')
# 2021-02-01 23:20:15,418 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/03gn1x Triple: ('/m/03gn1x', '/education/educational_institution/campuses', '/m/03gn1x')
# 2021-02-01 23:20:15,420 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/03gn1x Triple: ('/m/03gn1x', '/education/educational_institution/campuses', '/m/03gn1x')
# 2021-02-01 23:20:15,427 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/06mvyf Triple: ('/m/06mvyf', '/education/educational_institution/campuses', '/m/06mvyf')
# 2021-02-01 23:20:15,428 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/06mvyf Triple: ('/m/06mvyf', '/education/educational_institution/campuses', '/m/06mvyf')
# 2021-02-01 23:20:15,431 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0rp46 Triple: ('/m/0rp46', '/location/hud_county_place/place', '/m/0rp46')
# 2021-02-01 23:20:15,433 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0rp46 Triple: ('/m/0rp46', '/location/hud_county_place/place', '/m/0rp46')
# 2021-02-01 23:20:15,437 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/03zw80 Triple: ('/m/03zw80', '/education/educational_institution_campus/educational_institution', '/m/03zw80')
# 2021-02-01 23:20:15,438 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/03zw80 Triple: ('/m/03zw80', '/education/educational_institution_campus/educational_institution', '/m/03zw80')
# 2021-02-01 23:20:15,452 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0qpjt Triple: ('/m/0qpjt', '/location/hud_county_place/place', '/m/0qpjt')
# 2021-02-01 23:20:15,453 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0qpjt Triple: ('/m/0qpjt', '/location/hud_county_place/place', '/m/0qpjt')
# 2021-02-01 23:20:15,465 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/04rkkv Triple: ('/m/04rkkv', '/education/educational_institution/campuses', '/m/04rkkv')
# 2021-02-01 23:20:15,468 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/04rkkv Triple: ('/m/04rkkv', '/education/educational_institution/campuses', '/m/04rkkv')
# 2021-02-01 23:20:15,473 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/02txdf Triple: ('/m/02txdf', '/education/educational_institution/campuses', '/m/02txdf')
# 2021-02-01 23:20:15,474 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/02txdf Triple: ('/m/02txdf', '/education/educational_institution/campuses', '/m/02txdf')
# 2021-02-01 23:20:15,488 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/07w6r Triple: ('/m/07w6r', '/education/educational_institution_campus/educational_institution', '/m/07w6r')
# 2021-02-01 23:20:15,491 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/07w6r Triple: ('/m/07w6r', '/education/educational_institution_campus/educational_institution', '/m/07w6r')
# 2021-02-01 23:20:15,492 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01y888 Triple: ('/m/01y888', '/education/educational_institution_campus/educational_institution', '/m/01y888')
# 2021-02-01 23:20:15,494 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01y888 Triple: ('/m/01y888', '/education/educational_institution_campus/educational_institution', '/m/01y888')
# 2021-02-01 23:20:15,495 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0xkyn Triple: ('/m/0xkyn', '/location/hud_county_place/place', '/m/0xkyn')
# 2021-02-01 23:20:15,496 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0xkyn Triple: ('/m/0xkyn', '/location/hud_county_place/place', '/m/0xkyn')
# 2021-02-01 23:20:15,498 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0plxn Triple: ('/m/0plxn', '/location/hud_county_place/place', '/m/0plxn')
# 2021-02-01 23:20:15,500 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0plxn Triple: ('/m/0plxn', '/location/hud_county_place/place', '/m/0plxn')
# 2021-02-01 23:20:15,505 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/02w4v Triple: ('/m/02w4v', '/music/genre/artists', '/m/02w4v')
# 2021-02-01 23:20:15,506 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/02w4v Triple: ('/m/02w4v', '/music/genre/artists', '/m/02w4v')
# 2021-02-01 23:20:15,524 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0sxgh Triple: ('/m/0sxgh', '/education/educational_institution/campuses', '/m/0sxgh')
# 2021-02-01 23:20:15,526 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0sxgh Triple: ('/m/0sxgh', '/education/educational_institution/campuses', '/m/0sxgh')
# 2021-02-01 23:20:15,531 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/04gxp2 Triple: ('/m/04gxp2', '/education/educational_institution_campus/educational_institution', '/m/04gxp2')
# 2021-02-01 23:20:15,532 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/04gxp2 Triple: ('/m/04gxp2', '/education/educational_institution_campus/educational_institution', '/m/04gxp2')
# 2021-02-01 23:20:15,554 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/04sylm Triple: ('/m/04sylm', '/education/educational_institution/campuses', '/m/04sylm')
# 2021-02-01 23:20:15,556 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/04sylm Triple: ('/m/04sylm', '/education/educational_institution/campuses', '/m/04sylm')
# 2021-02-01 23:20:15,558 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/02r771y Triple: ('/m/02r771y', '/award/award_category/category_of', '/m/02r771y')
# 2021-02-01 23:20:15,559 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/02r771y Triple: ('/m/02r771y', '/award/award_category/category_of', '/m/02r771y')
# 2021-02-01 23:20:15,561 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01g0p5 Triple: ('/m/01g0p5', '/education/educational_institution_campus/educational_institution', '/m/01g0p5')
# 2021-02-01 23:20:15,562 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01g0p5 Triple: ('/m/01g0p5', '/education/educational_institution_campus/educational_institution', '/m/01g0p5')
# 2021-02-01 23:20:15,574 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0g8rj Triple: ('/m/0g8rj', '/education/educational_institution/campuses', '/m/0g8rj')
# 2021-02-01 23:20:15,576 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0g8rj Triple: ('/m/0g8rj', '/education/educational_institution/campuses', '/m/0g8rj')
# 2021-02-01 23:20:15,587 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0yt73 Triple: ('/m/0yt73', '/location/hud_county_place/place', '/m/0yt73')
# 2021-02-01 23:20:15,588 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0yt73 Triple: ('/m/0yt73', '/location/hud_county_place/place', '/m/0yt73')
# 2021-02-01 23:20:15,597 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0j1z8 Triple: ('/m/0j1z8', '/location/location/contains', '/m/0j1z8')
# 2021-02-01 23:20:15,598 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0j1z8 Triple: ('/m/0j1z8', '/location/location/contains', '/m/0j1z8')
# 2021-02-01 23:20:15,601 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0kyk Triple: ('/m/0kyk', '/dataworld/gardening_hint/split_to', '/m/0kyk')
# 2021-02-01 23:20:15,601 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0kyk Triple: ('/m/0kyk', '/dataworld/gardening_hint/split_to', '/m/0kyk')
# 2021-02-01 23:20:15,603 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0yz30 Triple: ('/m/0yz30', '/location/hud_county_place/place', '/m/0yz30')
# 2021-02-01 23:20:15,604 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0yz30 Triple: ('/m/0yz30', '/location/hud_county_place/place', '/m/0yz30')
# 2021-02-01 23:20:15,606 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01fpvz Triple: ('/m/01fpvz', '/education/educational_institution/campuses', '/m/01fpvz')
# 2021-02-01 23:20:15,606 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01fpvz Triple: ('/m/01fpvz', '/education/educational_institution/campuses', '/m/01fpvz')
# 2021-02-01 23:20:15,608 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/013dy7 Triple: ('/m/013dy7', '/location/hud_county_place/place', '/m/013dy7')
# 2021-02-01 23:20:15,610 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/013dy7 Triple: ('/m/013dy7', '/location/hud_county_place/place', '/m/013dy7')
# 2021-02-01 23:20:15,611 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/036921 Triple: ('/m/036921', '/education/educational_institution_campus/educational_institution', '/m/036921')
# 2021-02-01 23:20:15,612 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/036921 Triple: ('/m/036921', '/education/educational_institution_campus/educational_institution', '/m/036921')
# 2021-02-01 23:20:15,618 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01fy2s Triple: ('/m/01fy2s', '/education/educational_institution/campuses', '/m/01fy2s')
# 2021-02-01 23:20:15,620 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01fy2s Triple: ('/m/01fy2s', '/education/educational_institution/campuses', '/m/01fy2s')
# 2021-02-01 23:20:15,633 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/042tq Triple: ('/m/042tq', '/location/hud_county_place/place', '/m/042tq')
# 2021-02-01 23:20:15,634 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/042tq Triple: ('/m/042tq', '/location/hud_county_place/place', '/m/042tq')
# 2021-02-01 23:20:15,655 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/034q81 Triple: ('/m/034q81', '/education/educational_institution/campuses', '/m/034q81')
# 2021-02-01 23:20:15,657 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/034q81 Triple: ('/m/034q81', '/education/educational_institution/campuses', '/m/034q81')
# 2021-02-01 23:20:15,687 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/09b_0m Triple: ('/m/09b_0m', '/education/educational_institution_campus/educational_institution', '/m/09b_0m')
# 2021-02-01 23:20:15,689 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/09b_0m Triple: ('/m/09b_0m', '/education/educational_institution_campus/educational_institution', '/m/09b_0m')
# 2021-02-01 23:20:15,699 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/094jv Triple: ('/m/094jv', '/location/hud_county_place/county', '/m/094jv')
# 2021-02-01 23:20:15,700 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/094jv Triple: ('/m/094jv', '/location/hud_county_place/county', '/m/094jv')
# 2021-02-01 23:20:15,707 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/02kxx1 Triple: ('/m/02kxx1', '/education/educational_institution_campus/educational_institution', '/m/02kxx1')
# 2021-02-01 23:20:15,708 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/02kxx1 Triple: ('/m/02kxx1', '/education/educational_institution_campus/educational_institution', '/m/02kxx1')
# 2021-02-01 23:20:15,709 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0fvd03 Triple: ('/m/0fvd03', '/education/educational_institution_campus/educational_institution', '/m/0fvd03')
# 2021-02-01 23:20:15,710 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0fvd03 Triple: ('/m/0fvd03', '/education/educational_institution_campus/educational_institution', '/m/0fvd03')
# 2021-02-01 23:20:15,720 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/02q253 Triple: ('/m/02q253', '/education/educational_institution/campuses', '/m/02q253')
# 2021-02-01 23:20:15,721 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/02q253 Triple: ('/m/02q253', '/education/educational_institution/campuses', '/m/02q253')
# 2021-02-01 23:20:15,723 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/02mj7c Triple: ('/m/02mj7c', '/education/educational_institution_campus/educational_institution', '/m/02mj7c')
# 2021-02-01 23:20:15,724 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/02mj7c Triple: ('/m/02mj7c', '/education/educational_institution_campus/educational_institution', '/m/02mj7c')
# 2021-02-01 23:20:15,734 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/03fmfs Triple: ('/m/03fmfs', '/education/educational_institution_campus/educational_institution', '/m/03fmfs')
# 2021-02-01 23:20:15,736 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/03fmfs Triple: ('/m/03fmfs', '/education/educational_institution_campus/educational_institution', '/m/03fmfs')
# 2021-02-01 23:20:15,750 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0172jm Triple: ('/m/0172jm', '/education/educational_institution_campus/educational_institution', '/m/0172jm')
# 2021-02-01 23:20:15,752 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0172jm Triple: ('/m/0172jm', '/education/educational_institution_campus/educational_institution', '/m/0172jm')
# 2021-02-01 23:20:15,774 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01jszm Triple: ('/m/01jszm', '/education/educational_institution_campus/educational_institution', '/m/01jszm')
# 2021-02-01 23:20:15,779 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01jszm Triple: ('/m/01jszm', '/education/educational_institution_campus/educational_institution', '/m/01jszm')
# 2021-02-01 23:20:15,781 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/04thp Triple: ('/m/04thp', '/travel/tourist_attraction/near_travel_destination', '/m/04thp')
# 2021-02-01 23:20:15,783 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/04thp Triple: ('/m/04thp', '/travel/tourist_attraction/near_travel_destination', '/m/04thp')
# 2021-02-01 23:20:15,788 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/04sylm Triple: ('/m/04sylm', '/education/educational_institution_campus/educational_institution', '/m/04sylm')
# 2021-02-01 23:20:15,790 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/04sylm Triple: ('/m/04sylm', '/education/educational_institution_campus/educational_institution', '/m/04sylm')
# 2021-02-01 23:20:15,796 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01jpyb Triple: ('/m/01jpyb', '/education/educational_institution_campus/educational_institution', '/m/01jpyb')
# 2021-02-01 23:20:15,797 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01jpyb Triple: ('/m/01jpyb', '/education/educational_institution_campus/educational_institution', '/m/01jpyb')
# 2021-02-01 23:20:15,804 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0y62n Triple: ('/m/0y62n', '/location/us_county/county_seat', '/m/0y62n')
# 2021-02-01 23:20:15,806 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0y62n Triple: ('/m/0y62n', '/location/us_county/county_seat', '/m/0y62n')
# 2021-02-01 23:20:15,815 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0sgtz Triple: ('/m/0sgtz', '/location/hud_county_place/place', '/m/0sgtz')
# 2021-02-01 23:20:15,819 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0sgtz Triple: ('/m/0sgtz', '/location/hud_county_place/place', '/m/0sgtz')
# 2021-02-01 23:20:15,830 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/033f8n Triple: ('/m/033f8n', '/media_common/adaptation/adapted_from', '/m/033f8n')
# 2021-02-01 23:20:15,832 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/033f8n Triple: ('/m/033f8n', '/media_common/adaptation/adapted_from', '/m/033f8n')
# 2021-02-01 23:20:15,837 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0mn0v Triple: ('/m/0mn0v', '/location/us_county/hud_county_place', '/m/0mn0v')
# 2021-02-01 23:20:15,838 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0mn0v Triple: ('/m/0mn0v', '/location/us_county/hud_county_place', '/m/0mn0v')
# 2021-02-01 23:20:15,844 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/04d5v9 Triple: ('/m/04d5v9', '/education/educational_institution_campus/educational_institution', '/m/04d5v9')
# 2021-02-01 23:20:15,845 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/04d5v9 Triple: ('/m/04d5v9', '/education/educational_institution_campus/educational_institution', '/m/04d5v9')
# 2021-02-01 23:20:15,849 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01hjy5 Triple: ('/m/01hjy5', '/education/educational_institution/campuses', '/m/01hjy5')
# 2021-02-01 23:20:15,850 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01hjy5 Triple: ('/m/01hjy5', '/education/educational_institution/campuses', '/m/01hjy5')
# 2021-02-01 23:20:15,854 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0k2h6 Triple: ('/m/0k2h6', '/education/educational_institution_campus/educational_institution', '/m/0k2h6')
# 2021-02-01 23:20:15,855 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0k2h6 Triple: ('/m/0k2h6', '/education/educational_institution_campus/educational_institution', '/m/0k2h6')
# 2021-02-01 23:20:15,858 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0r8c8 Triple: ('/m/0r8c8', '/location/hud_county_place/place', '/m/0r8c8')
# 2021-02-01 23:20:15,862 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0r8c8 Triple: ('/m/0r8c8', '/location/hud_county_place/place', '/m/0r8c8')
# 2021-02-01 23:20:15,876 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/05qgd9 Triple: ('/m/05qgd9', '/education/educational_institution_campus/educational_institution', '/m/05qgd9')
# 2021-02-01 23:20:15,878 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/05qgd9 Triple: ('/m/05qgd9', '/education/educational_institution_campus/educational_institution', '/m/05qgd9')
# 2021-02-01 23:20:15,890 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0sg4x Triple: ('/m/0sg4x', '/location/hud_county_place/place', '/m/0sg4x')
# 2021-02-01 23:20:15,891 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0sg4x Triple: ('/m/0sg4x', '/location/hud_county_place/place', '/m/0sg4x')
# 2021-02-01 23:20:15,906 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/017y26 Triple: ('/m/017y26', '/education/educational_institution/campuses', '/m/017y26')
# 2021-02-01 23:20:15,908 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/017y26 Triple: ('/m/017y26', '/education/educational_institution/campuses', '/m/017y26')
# 2021-02-01 23:20:15,912 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0223xd Triple: ('/m/0223xd', '/award/award_category/category_of', '/m/0223xd')
# 2021-02-01 23:20:15,913 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0223xd Triple: ('/m/0223xd', '/award/award_category/category_of', '/m/0223xd')
# 2021-02-01 23:20:15,931 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01k8q5 Triple: ('/m/01k8q5', '/education/educational_institution/campuses', '/m/01k8q5')
# 2021-02-01 23:20:15,933 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01k8q5 Triple: ('/m/01k8q5', '/education/educational_institution/campuses', '/m/01k8q5')
# 2021-02-01 23:20:15,938 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0d6lp Triple: ('/m/0d6lp', '/location/us_county/county_seat', '/m/0d6lp')
# 2021-02-01 23:20:15,938 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0d6lp Triple: ('/m/0d6lp', '/location/us_county/county_seat', '/m/0d6lp')
# 2021-02-01 23:20:15,942 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0558_1 Triple: ('/m/0558_1', '/education/educational_institution/campuses', '/m/0558_1')
# 2021-02-01 23:20:15,946 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0558_1 Triple: ('/m/0558_1', '/education/educational_institution/campuses', '/m/0558_1')
# 2021-02-01 23:20:15,962 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01p5xy Triple: ('/m/01p5xy', '/education/educational_institution_campus/educational_institution', '/m/01p5xy')
# 2021-02-01 23:20:15,964 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01p5xy Triple: ('/m/01p5xy', '/education/educational_institution_campus/educational_institution', '/m/01p5xy')
# 2021-02-01 23:20:15,968 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0cwx_ Triple: ('/m/0cwx_', '/dataworld/gardening_hint/split_to', '/m/0cwx_')
# 2021-02-01 23:20:15,971 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0cwx_ Triple: ('/m/0cwx_', '/dataworld/gardening_hint/split_to', '/m/0cwx_')
# 2021-02-01 23:20:15,972 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0ymff Triple: ('/m/0ymff', '/education/educational_institution_campus/educational_institution', '/m/0ymff')
# 2021-02-01 23:20:15,974 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0ymff Triple: ('/m/0ymff', '/education/educational_institution_campus/educational_institution', '/m/0ymff')
# ...
# 2021-02-02 03:34:57,571 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0m4yg Triple: ('/m/0m4yg', '/education/educational_institution_campus/educational_institution', '/m/0m4yg')
# 2021-02-02 03:34:57,572 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0m4yg Triple: ('/m/0m4yg', '/education/educational_institution_campus/educational_institution', '/m/0m4yg')
# 2021-02-02 03:34:57,581 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/02bzh0 Triple: ('/m/02bzh0', '/education/educational_institution_campus/educational_institution', '/m/02bzh0')
# 2021-02-02 03:34:57,582 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/02bzh0 Triple: ('/m/02bzh0', '/education/educational_institution_campus/educational_institution', '/m/02bzh0')
# 2021-02-02 03:34:57,588 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/06wxw Triple: ('/m/06wxw', '/location/us_county/county_seat', '/m/06wxw')
# 2021-02-02 03:34:57,589 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/06wxw Triple: ('/m/06wxw', '/location/us_county/county_seat', '/m/06wxw')
# 2021-02-02 03:34:57,602 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0m2rv Triple: ('/m/0m2rv', '/location/hud_county_place/place', '/m/0m2rv')
# 2021-02-02 03:34:57,603 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0m2rv Triple: ('/m/0m2rv', '/location/hud_county_place/place', '/m/0m2rv')
# 2021-02-02 03:34:57,609 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/035ktt Triple: ('/m/035ktt', '/education/educational_institution_campus/educational_institution', '/m/035ktt')
# 2021-02-02 03:34:57,610 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/035ktt Triple: ('/m/035ktt', '/education/educational_institution_campus/educational_institution', '/m/035ktt')
# 2021-02-02 03:34:57,627 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0fnmz Triple: ('/m/0fnmz', '/education/educational_institution/campuses', '/m/0fnmz')
# 2021-02-02 03:34:57,628 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0fnmz Triple: ('/m/0fnmz', '/education/educational_institution/campuses', '/m/0fnmz')
# 2021-02-02 03:34:57,640 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/012fvq Triple: ('/m/012fvq', '/education/educational_institution/campuses', '/m/012fvq')
# 2021-02-02 03:34:57,643 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/012fvq Triple: ('/m/012fvq', '/education/educational_institution/campuses', '/m/012fvq')
# 2021-02-02 03:34:57,651 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/016dsy Triple: ('/m/016dsy', '/dataworld/gardening_hint/split_to', '/m/016dsy')
# 2021-02-02 03:34:57,652 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/016dsy Triple: ('/m/016dsy', '/dataworld/gardening_hint/split_to', '/m/016dsy')
# 2021-02-02 03:34:57,654 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0tln7 Triple: ('/m/0tln7', '/location/hud_county_place/place', '/m/0tln7')
# 2021-02-02 03:34:57,655 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0tln7 Triple: ('/m/0tln7', '/location/hud_county_place/place', '/m/0tln7')
# 2021-02-02 03:34:57,658 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/06rjp Triple: ('/m/06rjp', '/education/educational_institution/campuses', '/m/06rjp')
# 2021-02-02 03:34:57,659 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/06rjp Triple: ('/m/06rjp', '/education/educational_institution/campuses', '/m/06rjp')
# 2021-02-02 03:34:57,661 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01nds Triple: ('/m/01nds', '/dataworld/gardening_hint/split_to', '/m/01nds')
# 2021-02-02 03:34:57,663 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01nds Triple: ('/m/01nds', '/dataworld/gardening_hint/split_to', '/m/01nds')
# 2021-02-02 03:34:57,668 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/05xb7q Triple: ('/m/05xb7q', '/education/educational_institution_campus/educational_institution', '/m/05xb7q')
# 2021-02-02 03:34:57,669 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/05xb7q Triple: ('/m/05xb7q', '/education/educational_institution_campus/educational_institution', '/m/05xb7q')
# 2021-02-02 03:34:57,678 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/013l6l Triple: ('/m/013l6l', '/location/hud_county_place/place', '/m/013l6l')
# 2021-02-02 03:34:57,680 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/013l6l Triple: ('/m/013l6l', '/location/hud_county_place/place', '/m/013l6l')
# 2021-02-02 03:34:57,695 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/03x23q Triple: ('/m/03x23q', '/education/educational_institution/campuses', '/m/03x23q')
# 2021-02-02 03:34:57,697 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/03x23q Triple: ('/m/03x23q', '/education/educational_institution/campuses', '/m/03x23q')
# 2021-02-02 03:34:57,702 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/02sdwt Triple: ('/m/02sdwt', '/education/educational_institution_campus/educational_institution', '/m/02sdwt')
# 2021-02-02 03:34:57,704 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/02sdwt Triple: ('/m/02sdwt', '/education/educational_institution_campus/educational_institution', '/m/02sdwt')
# 2021-02-02 03:34:57,712 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/021s9n Triple: ('/m/021s9n', '/education/educational_institution/campuses', '/m/021s9n')
# 2021-02-02 03:34:57,713 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/021s9n Triple: ('/m/021s9n', '/education/educational_institution/campuses', '/m/021s9n')
# 2021-02-02 03:34:57,715 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01tx9m Triple: ('/m/01tx9m', '/education/educational_institution_campus/educational_institution', '/m/01tx9m')
# 2021-02-02 03:34:57,716 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01tx9m Triple: ('/m/01tx9m', '/education/educational_institution_campus/educational_institution', '/m/01tx9m')
# 2021-02-02 03:34:57,717 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0r4h3 Triple: ('/m/0r4h3', '/location/hud_county_place/place', '/m/0r4h3')
# 2021-02-02 03:34:57,719 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0r4h3 Triple: ('/m/0r4h3', '/location/hud_county_place/place', '/m/0r4h3')
# 2021-02-02 03:34:57,738 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/02jxsq Triple: ('/m/02jxsq', '/dataworld/gardening_hint/split_to', '/m/02jxsq')
# 2021-02-02 03:34:57,740 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/02jxsq Triple: ('/m/02jxsq', '/dataworld/gardening_hint/split_to', '/m/02jxsq')
# 2021-02-02 03:34:57,750 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0h6rm Triple: ('/m/0h6rm', '/education/educational_institution_campus/educational_institution', '/m/0h6rm')
# 2021-02-02 03:34:57,751 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0h6rm Triple: ('/m/0h6rm', '/education/educational_institution_campus/educational_institution', '/m/0h6rm')
# 2021-02-02 03:34:57,753 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/034lk7 Triple: ('/m/034lk7', '/location/us_county/county_seat', '/m/034lk7')
# 2021-02-02 03:34:57,755 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/034lk7 Triple: ('/m/034lk7', '/location/us_county/county_seat', '/m/034lk7')
# 2021-02-02 03:34:57,766 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/02fjzt Triple: ('/m/02fjzt', '/education/educational_institution_campus/educational_institution', '/m/02fjzt')
# 2021-02-02 03:34:57,768 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/02fjzt Triple: ('/m/02fjzt', '/education/educational_institution_campus/educational_institution', '/m/02fjzt')
# 2021-02-02 03:34:57,777 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01pxcf Triple: ('/m/01pxcf', '/education/educational_institution_campus/educational_institution', '/m/01pxcf')
# 2021-02-02 03:34:57,779 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01pxcf Triple: ('/m/01pxcf', '/education/educational_institution_campus/educational_institution', '/m/01pxcf')
# 2021-02-02 03:34:57,781 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/02w6bq Triple: ('/m/02w6bq', '/education/educational_institution_campus/educational_institution', '/m/02w6bq')
# 2021-02-02 03:34:57,782 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/02w6bq Triple: ('/m/02w6bq', '/education/educational_institution_campus/educational_institution', '/m/02w6bq')
# 2021-02-02 03:34:57,785 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01bdhf Triple: ('/m/01bdhf', '/education/educational_institution_campus/educational_institution', '/m/01bdhf')
# 2021-02-02 03:34:57,786 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01bdhf Triple: ('/m/01bdhf', '/education/educational_institution_campus/educational_institution', '/m/01bdhf')
# 2021-02-02 03:34:57,796 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/02rff2 Triple: ('/m/02rff2', '/education/educational_institution_campus/educational_institution', '/m/02rff2')
# 2021-02-02 03:34:57,799 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/02rff2 Triple: ('/m/02rff2', '/education/educational_institution_campus/educational_institution', '/m/02rff2')
# 2021-02-02 03:34:57,809 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0mnm2 Triple: ('/m/0mnm2', '/location/hud_county_place/county', '/m/0mnm2')
# 2021-02-02 03:34:57,810 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0mnm2 Triple: ('/m/0mnm2', '/location/hud_county_place/county', '/m/0mnm2')
# 2021-02-02 03:34:57,818 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/01trxd Triple: ('/m/01trxd', '/education/educational_institution_campus/educational_institution', '/m/01trxd')
# 2021-02-02 03:34:57,820 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/01trxd Triple: ('/m/01trxd', '/education/educational_institution_campus/educational_institution', '/m/01trxd')
# 2021-02-02 03:34:57,825 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/02c_4 Triple: ('/m/02c_4', '/user/szaijan/fantasy_football/player/nfl_team', '/m/02c_4')
# 2021-02-02 03:34:57,826 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/02c_4 Triple: ('/m/02c_4', '/user/szaijan/fantasy_football/player/nfl_team', '/m/02c_4')
# 2021-02-02 03:34:57,850 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0pc56 Triple: ('/m/0pc56', '/location/hud_county_place/place', '/m/0pc56')
# 2021-02-02 03:34:57,853 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0pc56 Triple: ('/m/0pc56', '/location/hud_county_place/place', '/m/0pc56')
# 2021-02-02 03:34:57,881 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0l_q9 Triple: ('/m/0l_q9', '/location/hud_county_place/county', '/m/0l_q9')
# 2021-02-02 03:34:57,883 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0l_q9 Triple: ('/m/0l_q9', '/location/hud_county_place/county', '/m/0l_q9')
# 2021-02-02 03:34:57,885 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/045xh Triple: ('/m/045xh', '/award/award_category/category_of', '/m/045xh')
# 2021-02-02 03:34:57,886 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/045xh Triple: ('/m/045xh', '/award/award_category/category_of', '/m/045xh')
# 2021-02-02 03:34:57,896 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/07w5rq Triple: ('/m/07w5rq', '/education/educational_institution_campus/educational_institution', '/m/07w5rq')
# 2021-02-02 03:34:57,898 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/07w5rq Triple: ('/m/07w5rq', '/education/educational_institution_campus/educational_institution', '/m/07w5rq')
# 2021-02-02 03:34:57,916 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0bxc4 Triple: ('/m/0bxc4', '/location/hud_county_place/place', '/m/0bxc4')
# 2021-02-02 03:34:57,917 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0bxc4 Triple: ('/m/0bxc4', '/location/hud_county_place/place', '/m/0bxc4')
# 2021-02-02 03:34:57,920 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/02pdhz Triple: ('/m/02pdhz', '/education/educational_institution_campus/educational_institution', '/m/02pdhz')
# 2021-02-02 03:34:57,922 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/02pdhz Triple: ('/m/02pdhz', '/education/educational_institution_campus/educational_institution', '/m/02pdhz')
# 2021-02-02 03:34:57,933 - root - ERROR - ERROR: Failed to retrieve head predictions for (correct) head concept: /m/0_565 Triple: ('/m/0_565', '/location/hud_county_place/place', '/m/0_565')
# 2021-02-02 03:34:57,935 - root - ERROR - ERROR: Failed to retrieve tail predictions for (correct) tail concept: /m/0_565 Triple: ('/m/0_565', '/location/hud_county_place/place', '/m/0_565')
# 2021-02-02 03:34:57,937 - root - INFO - Mean Head Rank: 343.653193154367 (220 ignored lines)
# Mean Reciprocal Head Rank: 0.16455951826176843 (220 ignored lines)
# 2021-02-02 03:34:57,938 - root - INFO - Mean Tail Rank: 454.50819978905105 (220 ignored lines)
# Mean Reciprocal Tail Rank: 0.24832155766175093 (220 ignored lines)
# 2021-02-02 03:34:57,938 - root - INFO - Mean rank: 399.080696471709; rounded: 399
# 2021-02-02 03:34:57,939 - root - INFO - Mean reciprocal rank: 0.20644053796175968
# Reading provided file...
# 2021-02-02 03:37:47,583 - kbc_evaluation.dataset - INFO - Apply Filtering
# 2021-02-02 03:37:47,686 - kbc_evaluation.dataset - INFO - Read Training File
# 2021-02-02 03:39:22,180 - kbc_evaluation.dataset - INFO - Read Validation File
# 2021-02-02 03:39:22,441 - kbc_evaluation.dataset - INFO - Read Test File
#  84%|████████▍ | 49592/59002 [20:29<04:35, 34.15it/s]

# %% [markdown]
# ## Let's Render our Evaluation Results
# We have already individual evaluation files written to disk. Now, let's quickly render an HTML table.

# %%
from IPython.display import display, HTML
from typing import Dict, List
from kbc_evaluation.evaluator import EvaluatorResult 
import os
import pickle

work_dir = "/work/jportisc/kbc_rdf2vec/strategy_grid_2/evaluation_2"
prediction_path = os.path.join(work_dir, "predictions")

def transform_result_list_to_html(result_map: List[Dict[str, List[EvaluatorResult]]]) -> str:
    if "result_map" not in globals() or result_map is None:
        with open(os.path.join(work_dir, "predictions", "result_map.pickle"), 'rb') as f:
            print("Loading result_map from disk.")
            result_map = pickle.load(f)
    
    first_entry = next(iter(result_map.values()))
    
    if first_entry[0].n is not None:
        n = first_entry[0].n
    elif first_entry[1].n is not None:
        n = first_entry[1].n
    else:
        n = "?"
    
    result = f"""
        <table style="border: 1px solid black;">
            <tr>
                <td>&nbsp;</td>
                <td colspan="6"><center><b>WN18</b></center></td>
                <td colspan="6"><center><b>FB15k</b></center></td>
            </tr>
            <tr>
                <td>Metric</td>
                <td colspan="2"><center>Mean Rank (all)</center></td>
                <td colspan="2"><center>HITS@{n} (all)</center></td>
                <td colspan="2"><center>RelativeHITS@{n} (all)</center></td>
                <td colspan="2"><center>Mean Rank (all)</center></td>
                <td colspan="2"><center>HITS@{n} (all)</center></td>
                <td colspan="2"><center>RelativeHITS@{n} (all)</center></td>
            <tr>
            <tr>
                <td>Evaluation Setting</td>
                <td>Raw</td>
                <td>Filtered</td>
                <td>Raw</td>
                <td>Filtered</td>
                <td>Raw</td>
                <td>Filtered</td>
                <td>Raw</td>
                <td>Filtered</td>
                <td>Raw</td>
                <td>Filtered</td>
                <td>Raw</td>
                <td>Filtered</td>
            </tr>
        """    
    
    for setting, entry in result_map.items():
        result = result + f"""
            <tr>
                <td>{setting}</td>
            """
        if entry[0] is not None:
            result = result + f"""
                <td>{entry[0].non_filtered_mean_rank_all}</td>
                <td>{entry[0].filtered_mean_rank_all}</td>
                <td>{entry[0].non_filtered_hits_at_n_all}</td>
                <td>{entry[0].filtered_hits_at_n_all}</td>
                <td>{round(entry[0].non_filtered_hits_at_n_relative, 4)}</td>
                <td>{round(entry[0].filtered_hits_at_n_relative, 4)}</td>
            """
        else:
            result = result + f"""
                <td>&nbsp;</td>
                <td>&nbsp;</td>
                <td>&nbsp;</td>
                <td>&nbsp;</td>
                <td>&nbsp;</td>
                <td>&nbsp;</td>
            """
        if entry [1] is not None:
            result = result + f"""
                <td>{entry[1].non_filtered_mean_rank_all}</td>
                <td>{entry[1].filtered_mean_rank_all}</td>
                <td>{entry[1].non_filtered_hits_at_n_all}</td>
                <td>{entry[1].filtered_hits_at_n_all}</td>
                <td>{round(entry[1].non_filtered_hits_at_n_relative, 4)}</td>
                <td>{round(entry[1].filtered_hits_at_n_relative, 4)}</td>
            """
        else:
             result = result + f"""
                <td>&nbsp;</td>
                <td>&nbsp;</td>
                <td>&nbsp;</td>
                <td>&nbsp;</td>
                <td>&nbsp;</td>
                <td>&nbsp;</td>
            """
        
        result = result + "</tr>"
    
    result = result + "\n</table>"
    return result


display(HTML(transform_result_list_to_html(None)))
# Out:
# Loading result_map from disk.
#         <table style="border: 1px solid black;">
#             <tr>
#                 <td>&nbsp;</td>
#                 <td colspan="6"><center><b>WN18</b></center></td>
#                 <td colspan="6"><center><b>FB15k</b></center></td>
#             </tr>
#             <tr>
#                 <td>Metric</td>
#                 <td colspan="2"><center>Mean Rank (all)</center></td>
#                 <td colspan="2"><center>HITS@10 (all)</center></td>
#                 <td colspan="2"><center>RelativeHITS@10 (all)</center></td>
#                 <td colspan="2"><center>Mean Rank (all)</center></td>
#                 <td colspan="2"><center>HITS@10 (all)</center></td>
#                 <td colspan="2"><center>RelativeHITS@10 (all)</center></td>
#             <tr>
#             <tr>
#                 <td>Evaluation Setting</td>
#                 <td>Raw</td>
#                 <td>Filtered</td>
#                 <td>Raw</td>
#                 <td>Filtered</td>
#                 <td>Raw</td>
#                 <td>Filtered</td>
#                 <td>Raw</td>
#                 <td>Filtered</td>
#                 <td>Raw</td>
#                 <td>Filtered</td>
#                 <td>Raw</td>
#                 <td>Filtered</td>
#             </tr>
#
#             <tr>
#                 <td>ANN</td>
#
#                 <td>353</td>
#                 <td>342</td>
#                 <td>4968</td>
#                 <td>5543</td>
#                 <td>0.4968</td>
#                 <td>0.5543</td>
#
#                 <td>349</td>
#                 <td>303</td>
#                 <td>40460</td>
#                 <td>49392</td>
#                 <td>0.3425</td>
#                 <td>0.4181</td>
#             </tr>
#             <tr>
#                 <td>most_similar(H, L)</td>
#
#                 <td>180</td>
#                 <td>168</td>
#                 <td>6080</td>
#                 <td>6533</td>
#                 <td>0.608</td>
#                 <td>0.6533</td>
#
#                 <td>427</td>
#                 <td>368</td>
#                 <td>39578</td>
#                 <td>44243</td>
#                 <td>0.335</td>
#                 <td>0.3745</td>
#             </tr>
#             <tr>
#                 <td>most_similar(H, AVG(T-H))</td>
#
#                 <td>180</td>
#                 <td>168</td>
#                 <td>6080</td>
#                 <td>6533</td>
#                 <td>0.608</td>
#                 <td>0.6533</td>
#
#                 <td>1953</td>
#                 <td>1845</td>
#                 <td>12486</td>
#                 <td>16260</td>
#                 <td>0.1057</td>
#                 <td>0.1376</td>
#             </tr>
#             <tr>
#                 <td>most_similar(H + L)</td>
#
#                 <td>167</td>
#                 <td>154</td>
#                 <td>6347</td>
#                 <td>6978</td>
#                 <td>0.6347</td>
#                 <td>0.6978</td>
#
#                 <td>1011</td>
#                 <td>955</td>
#                 <td>31102</td>
#                 <td>33860</td>
#                 <td>0.2633</td>
#                 <td>0.2866</td>
#             </tr>
#             <tr>
#                 <td>most_similar(H + AVG(T-H))</td>
#
#                 <td>147</td>
#                 <td>135</td>
#                 <td>6439</td>
#                 <td>7133</td>
#                 <td>0.6439</td>
#                 <td>0.7133</td>
#
#                 <td>399</td>
#                 <td>347</td>
#                 <td>41714</td>
#                 <td>47890</td>
#                 <td>0.3531</td>
#                 <td>0.4054</td>
#             </tr>
#             <tr>
#                 <td>most_similar(H + L) reflexive</td>
#
#                 <td>&nbsp;</td>
#                 <td>&nbsp;</td>
#                 <td>&nbsp;</td>
#                 <td>&nbsp;</td>
#                 <td>&nbsp;</td>
#                 <td>&nbsp;</td>
#
#                 <td>1008</td>
#                 <td>952</td>
#                 <td>31231</td>
#                 <td>33952</td>
#                 <td>0.2644</td>
#                 <td>0.2874</td>
#             </tr>
#             <tr>
#                 <td>most_similar(H + AVG(T-H)) reflexive</td>
#
#                 <td>&nbsp;</td>
#                 <td>&nbsp;</td>
#                 <td>&nbsp;</td>
#                 <td>&nbsp;</td>
#                 <td>&nbsp;</td>
#                 <td>&nbsp;</td>
#
#                 <td>398</td>
#                 <td>346</td>
#                 <td>41610</td>
#                 <td>47741</td>
#                 <td>0.3522</td>
#                 <td>0.4041</td>
#             </tr>
# </table>
