# %% [markdown]
# # Knowledge Base Completion (KBC) / Link Prediction with RDF2Vec

# %% [markdown]
# ## Prerequisites (Linux/MacOS)
#
# - install kbc_rdf2vec ([https://github.com/janothan/kbc_rdf2vec](https://github.com/janothan/kbc_rdf2vec))
# - install kbc_evaluation ([https://github.com/janothan/kbc_evaluation/](https://github.com/janothan/kbc_evaluation/))
# - install jRDF2Vec and add the shell script to your path (see [here](https://github.com/dwslab/jRDF2Vec/blob/master/src/main/bin/jrdf2vec.sh)) - alternatively, you can modify the specified jrdf2vec command in this notebook to fit your path.
#
# The only thing you have to do before running the whole notebook is to set your `work_dir` in the cell below.

# %%
# TODO: Now let's decide on your directory where everything shall be written to (requires > 5Gb of disk space)
work_dir = "/work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files"

# %% [markdown]
# ## Let's Transform WN18 and FB15k Into NT Files

# %%
import sys
from kbc_rdf2vec.dataset import DataSet
import os

# create the directory if it does not exist yet
nt_dir = os.path.join(work_dir, "nt_files")
if not os.path.exists(nt_dir):
    os.makedirs(nt_dir)

DataSet.write_training_file_nt(data_set=DataSet.WN18, file_to_write=os.path.join(nt_dir, "WN18.nt"))
DataSet.write_training_file_nt(data_set=DataSet.FB15K, file_to_write=os.path.join(nt_dir, "FB15k.nt"))

# %% [markdown]
# ## Let's Train Embeddings with jRDF2Vec
#
# Train embeddings for WN18 by running the following line:
# ```
# !jrdf2vec -graph "./WN18.nt" -numberOfWalks 300 -threads 20 -depth 4 -walkDirectory <set manually or use generated statement> -trainingMode sg -dimension 200 -window 2 -epochs 25
# ```
#
# Train embeddings for FB15k by running the following line:
# ```
# !jrdf2vec -graph "./FB15k.nt" -numberOfWalks 300 -threads 20 -depth 4 -walkDirectory <set manually or use generated statement> -trainingMode sg -dimension 200 -window 2 -epochs 25
# ```
#
# You do not have to do anything except for running the cells below.

# %%
wn18_walk_path = os.path.join(work_dir, "wn18_walks")
wn_nt_path = os.path.join(nt_dir, "WN18.nt")

# !jrdf2vec -graph $wn_nt_path -numberOfWalks 250 -threads 20 -depth 4 -walkDirectory $wn18_walk_path -trainingMode sg -dimension 200 -window 2 -epochs 25
# Out:
# The specified walk directory does not exist. Trying to make the directory.
# Using 20 threads for walk generation and training.
# Using vector dimension: 200
# Using depth 4
# Generating 250 walks per entity.
# RDF2Vec Classic
#  INFO [main] (ParserManager.java:53) - Using NxParser.
#  INFO [main] (ParserManager.java:88) - Model read into memory.
# walkGeneration mode is null... Using default: RANDOM_WALKS_DUPLICATE_FREE
#  INFO [pool-1-thread-1] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 1000
#  INFO [pool-1-thread-1] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 236230
#  INFO [pool-1-thread-6] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 2000
#  INFO [pool-1-thread-6] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 472839
#  INFO [pool-1-thread-4] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 3000
#  INFO [pool-1-thread-4] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 709585
#  INFO [pool-1-thread-2] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 4000
#  INFO [pool-1-thread-2] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 946911
#  INFO [pool-1-thread-10] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 5000
#  INFO [pool-1-thread-10] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 1182876
#  INFO [pool-1-thread-2] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 6000
#  INFO [pool-1-thread-2] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 1419894
#  INFO [pool-1-thread-7] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 7000
#  INFO [pool-1-thread-7] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 1652140
#  INFO [pool-1-thread-15] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 8000
#  INFO [pool-1-thread-15] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 1887734
#  INFO [pool-1-thread-15] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 9000
#  INFO [pool-1-thread-15] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 2124996
#  INFO [pool-1-thread-2] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 10000
#  INFO [pool-1-thread-2] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 2361216
#  INFO [pool-1-thread-18] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 11000
#  INFO [pool-1-thread-18] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 2596224
#  INFO [pool-1-thread-6] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 12000
#  INFO [pool-1-thread-6] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 2831488
#  INFO [pool-1-thread-14] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 13000
#  INFO [pool-1-thread-14] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 3067960
#  INFO [pool-1-thread-4] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 14000
#  INFO [pool-1-thread-4] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 3305101
#  INFO [pool-1-thread-20] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 15000
#  INFO [pool-1-thread-20] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 3540801
#  INFO [pool-1-thread-20] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 16000
#  INFO [pool-1-thread-20] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 3777714
#  INFO [pool-1-thread-9] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 17000
#  INFO [pool-1-thread-9] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 4013563
#  INFO [pool-1-thread-13] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 18000
#  INFO [pool-1-thread-13] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 4248674
#  INFO [pool-1-thread-15] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 19000
#  INFO [pool-1-thread-15] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 4483619
#  INFO [pool-1-thread-15] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 20000
#  INFO [pool-1-thread-15] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 4721363
#  INFO [pool-1-thread-8] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 21000
#  INFO [pool-1-thread-8] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 4958471
#  INFO [pool-1-thread-3] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 22000
#  INFO [pool-1-thread-3] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 5194768
#  INFO [pool-1-thread-3] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 23000
#  INFO [pool-1-thread-3] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 5432549
#  INFO [pool-1-thread-1] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 24000
#  INFO [pool-1-thread-1] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 5672183
#  INFO [pool-1-thread-18] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 25000
#  INFO [pool-1-thread-18] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 5907173
#  INFO [pool-1-thread-20] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 26000
#  INFO [pool-1-thread-20] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 6143323
#  INFO [pool-1-thread-20] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 27000
#  INFO [pool-1-thread-20] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 6380629
#  INFO [pool-1-thread-20] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 28000
#  INFO [pool-1-thread-20] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 6616408
#  INFO [pool-1-thread-5] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 29000
#  INFO [pool-1-thread-5] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 6850564
#  INFO [pool-1-thread-5] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 30000
#  INFO [pool-1-thread-5] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 7084348
#  INFO [pool-1-thread-1] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 31000
#  INFO [pool-1-thread-1] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 7321381
#  INFO [pool-1-thread-16] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 32000
#  INFO [pool-1-thread-16] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 7555646
#  INFO [pool-1-thread-19] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 33000
#  INFO [pool-1-thread-19] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 7789625
#  INFO [pool-1-thread-11] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 34000
#  INFO [pool-1-thread-11] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 8025179
#  INFO [pool-1-thread-12] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 35000
#  INFO [pool-1-thread-12] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 8258980
#  INFO [pool-1-thread-16] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 36000
#  INFO [pool-1-thread-16] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 8496818
#  INFO [pool-1-thread-4] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 37000
#  INFO [pool-1-thread-4] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 8734700
#  INFO [pool-1-thread-11] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 38000
#  INFO [pool-1-thread-11] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 8970943
#  INFO [pool-1-thread-6] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 39000
#  INFO [pool-1-thread-6] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 9208884
#  INFO [pool-1-thread-17] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 40000
#  INFO [pool-1-thread-17] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 9446866
# DEBUG [main] (RequestAddCookies.java:123) - CookieSpec selected: default
# DEBUG [main] (RequestAuthCache.java:77) - Auth cache not set in the context
# DEBUG [main] (PoolingHttpClientConnectionManager.java:266) - Connection request: [route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:310) - Connection leased: [id: 0][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 1 of 2; total allocated: 1 of 20]
# DEBUG [main] (MainClientExec.java:234) - Opening connection {}->http://127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:139) - Connecting to /127.0.0.1:1808
# DEBUG [main] (LoggingManagedHttpClientConnection.java:96) - http-outgoing-0: Shutdown connection
# DEBUG [main] (ConnectionHolder.java:129) - Connection discarded
# DEBUG [main] (PoolingHttpClientConnectionManager.java:349) - Connection released: [id: 0][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
#  INFO [main] (Gensim.java:582) - Server is not yet running. Waiting 5 seconds. Trial 1 / 8
# DEBUG [main] (PoolingHttpClientConnectionManager.java:409) - Connection manager is shutting down
# DEBUG [main] (PoolingHttpClientConnectionManager.java:415) - Connection manager shut down
# DEBUG [main] (RequestAddCookies.java:123) - CookieSpec selected: default
# DEBUG [main] (RequestAuthCache.java:77) - Auth cache not set in the context
# DEBUG [main] (PoolingHttpClientConnectionManager.java:266) - Connection request: [route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:310) - Connection leased: [id: 1][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 1 of 2; total allocated: 1 of 20]
# DEBUG [main] (MainClientExec.java:234) - Opening connection {}->http://127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:139) - Connecting to /127.0.0.1:1808
# DEBUG [main] (LoggingManagedHttpClientConnection.java:96) - http-outgoing-1: Shutdown connection
# DEBUG [main] (ConnectionHolder.java:129) - Connection discarded
# DEBUG [main] (PoolingHttpClientConnectionManager.java:349) - Connection released: [id: 1][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
#  INFO [main] (Gensim.java:582) - Server is not yet running. Waiting 5 seconds. Trial 2 / 8
# DEBUG [main] (PoolingHttpClientConnectionManager.java:409) - Connection manager is shutting down
# DEBUG [main] (PoolingHttpClientConnectionManager.java:415) - Connection manager shut down
# DEBUG [main] (RequestAddCookies.java:123) - CookieSpec selected: default
# DEBUG [main] (RequestAuthCache.java:77) - Auth cache not set in the context
# DEBUG [main] (PoolingHttpClientConnectionManager.java:266) - Connection request: [route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:310) - Connection leased: [id: 2][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 1 of 2; total allocated: 1 of 20]
# DEBUG [main] (MainClientExec.java:234) - Opening connection {}->http://127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:139) - Connecting to /127.0.0.1:1808
# DEBUG [main] (LoggingManagedHttpClientConnection.java:96) - http-outgoing-2: Shutdown connection
# DEBUG [main] (ConnectionHolder.java:129) - Connection discarded
# DEBUG [main] (PoolingHttpClientConnectionManager.java:349) - Connection released: [id: 2][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
#  INFO [main] (Gensim.java:582) - Server is not yet running. Waiting 5 seconds. Trial 3 / 8
# DEBUG [main] (PoolingHttpClientConnectionManager.java:409) - Connection manager is shutting down
# DEBUG [main] (PoolingHttpClientConnectionManager.java:415) - Connection manager shut down
# DEBUG [main] (RequestAddCookies.java:123) - CookieSpec selected: default
# DEBUG [main] (RequestAuthCache.java:77) - Auth cache not set in the context
# DEBUG [main] (PoolingHttpClientConnectionManager.java:266) - Connection request: [route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:310) - Connection leased: [id: 3][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 1 of 2; total allocated: 1 of 20]
# DEBUG [main] (MainClientExec.java:234) - Opening connection {}->http://127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:139) - Connecting to /127.0.0.1:1808
# DEBUG [main] (LoggingManagedHttpClientConnection.java:96) - http-outgoing-3: Shutdown connection
# DEBUG [main] (ConnectionHolder.java:129) - Connection discarded
# DEBUG [main] (PoolingHttpClientConnectionManager.java:349) - Connection released: [id: 3][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
#  INFO [main] (Gensim.java:582) - Server is not yet running. Waiting 5 seconds. Trial 4 / 8
#  * Serving Flask app "python_server" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# DEBUG [main] (PoolingHttpClientConnectionManager.java:409) - Connection manager is shutting down
# DEBUG [main] (PoolingHttpClientConnectionManager.java:415) - Connection manager shut down
# DEBUG [main] (RequestAddCookies.java:123) - CookieSpec selected: default
# DEBUG [main] (RequestAuthCache.java:77) - Auth cache not set in the context
# DEBUG [main] (PoolingHttpClientConnectionManager.java:266) - Connection request: [route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:310) - Connection leased: [id: 4][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 1 of 2; total allocated: 1 of 20]
# DEBUG [main] (MainClientExec.java:234) - Opening connection {}->http://127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:139) - Connecting to /127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:146) - Connection established 127.0.0.1:51968<->127.0.0.1:1808
# DEBUG [main] (MainClientExec.java:255) - Executing request GET /melt_ml.html HTTP/1.1
# DEBUG [main] (MainClientExec.java:260) - Target auth state: UNCHALLENGED
# DEBUG [main] (MainClientExec.java:266) - Proxy auth state: UNCHALLENGED
# DEBUG [main] (LoggingManagedHttpClientConnection.java:133) - http-outgoing-4 >> GET /melt_ml.html HTTP/1.1
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> Host: 127.0.0.1:1808
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> Connection: Keep-Alive
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> User-Agent: Apache-HttpClient/4.5.10 (Java/11.0.8)
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-4 >> Accept-Encoding: gzip,deflate
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "GET /melt_ml.html HTTP/1.1[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "Host: 127.0.0.1:1808[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "Connection: Keep-Alive[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "User-Agent: Apache-HttpClient/4.5.10 (Java/11.0.8)[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "Accept-Encoding: gzip,deflate[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 >> "[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 << "HTTP/1.0 200 OK[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 << "Content-Type: text/html; charset=utf-8[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 << "Content-Length: 49[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 << "Server: Werkzeug/1.0.1 Python/3.8.3[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 << "Date: Thu, 14 Jan 2021 07:20:41 GMT[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-4 << "[\r][\n]"
# DEBUG [main] (Wire.java:87) - http-outgoing-4 << "MELT ML Server running. Ready to accept requests."
# DEBUG [main] (LoggingManagedHttpClientConnection.java:122) - http-outgoing-4 << HTTP/1.0 200 OK
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-4 << Content-Type: text/html; charset=utf-8
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-4 << Content-Length: 49
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-4 << Server: Werkzeug/1.0.1 Python/3.8.3
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-4 << Date: Thu, 14 Jan 2021 07:20:41 GMT
#  INFO [main] (Gensim.java:578) - Server is running.
# DEBUG [main] (LoggingManagedHttpClientConnection.java:79) - http-outgoing-4: Close connection
# DEBUG [main] (ConnectionHolder.java:104) - Connection discarded
# DEBUG [main] (PoolingHttpClientConnectionManager.java:349) - Connection released: [id: 4][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# ERROR [main] (Gensim.java:413) - ERROR: The specified model path does not exist or is a directory.
# ERROR [main] (Gensim.java:414) - Provided file path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/wn18_walks
# DEBUG [main] (RequestAddCookies.java:123) - CookieSpec selected: default
# DEBUG [main] (RequestAuthCache.java:77) - Auth cache not set in the context
# DEBUG [main] (PoolingHttpClientConnectionManager.java:266) - Connection request: [route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:310) - Connection leased: [id: 5][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 1 of 2; total allocated: 1 of 20]
# DEBUG [main] (MainClientExec.java:234) - Opening connection {}->http://127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:139) - Connecting to /127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:146) - Connection established 127.0.0.1:51970<->127.0.0.1:1808
# DEBUG [main] (MainClientExec.java:255) - Executing request GET /train-word2vec HTTP/1.1
# DEBUG [main] (MainClientExec.java:260) - Target auth state: UNCHALLENGED
# DEBUG [main] (MainClientExec.java:266) - Proxy auth state: UNCHALLENGED
# DEBUG [main] (LoggingManagedHttpClientConnection.java:133) - http-outgoing-5 >> GET /train-word2vec HTTP/1.1
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> vector_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/wn18_walks/model.kv
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> model_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/wn18_walks/model
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> file_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/wn18_walks
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> vector_dimension: 200
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> number_of_threads: 20
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> window_size: 2
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> iterations: 5
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> negatives: 5
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> cbow_or_sg: sg
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> min_count: 1
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> sample: 0.0
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> epochs: 25
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> Host: 127.0.0.1:1808
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> Connection: Keep-Alive
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> User-Agent: Apache-HttpClient/4.5.10 (Java/11.0.8)
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-5 >> Accept-Encoding: gzip,deflate
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "GET /train-word2vec HTTP/1.1[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "vector_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/wn18_walks/model.kv[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "model_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/wn18_walks/model[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "file_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/wn18_walks[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "vector_dimension: 200[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "number_of_threads: 20[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "window_size: 2[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "iterations: 5[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "negatives: 5[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "cbow_or_sg: sg[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "min_count: 1[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "sample: 0.0[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "epochs: 25[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "Host: 127.0.0.1:1808[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "Connection: Keep-Alive[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "User-Agent: Apache-HttpClient/4.5.10 (Java/11.0.8)[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "Accept-Encoding: gzip,deflate[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 >> "[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 << "HTTP/1.0 200 OK[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 << "Content-Type: text/html; charset=utf-8[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 << "Content-Length: 4[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 << "Server: Werkzeug/1.0.1 Python/3.8.3[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 << "Date: Thu, 14 Jan 2021 09:03:50 GMT[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-5 << "[\r][\n]"
# DEBUG [main] (Wire.java:87) - http-outgoing-5 << "True"
# DEBUG [main] (LoggingManagedHttpClientConnection.java:122) - http-outgoing-5 << HTTP/1.0 200 OK
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-5 << Content-Type: text/html; charset=utf-8
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-5 << Content-Length: 4
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-5 << Server: Werkzeug/1.0.1 Python/3.8.3
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-5 << Date: Thu, 14 Jan 2021 09:03:50 GMT
# DEBUG [main] (LoggingManagedHttpClientConnection.java:79) - http-outgoing-5: Close connection
# DEBUG [main] (ConnectionHolder.java:104) - Connection discarded
# DEBUG [main] (PoolingHttpClientConnectionManager.java:349) - Connection released: [id: 5][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (RequestAddCookies.java:123) - CookieSpec selected: default
# DEBUG [main] (RequestAuthCache.java:77) - Auth cache not set in the context
# DEBUG [main] (PoolingHttpClientConnectionManager.java:266) - Connection request: [route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:310) - Connection leased: [id: 6][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 1 of 2; total allocated: 1 of 20]
# DEBUG [main] (MainClientExec.java:234) - Opening connection {}->http://127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:139) - Connecting to /127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:146) - Connection established 127.0.0.1:52160<->127.0.0.1:1808
# DEBUG [main] (MainClientExec.java:255) - Executing request GET /write-model-as-text-file HTTP/1.1
# DEBUG [main] (MainClientExec.java:260) - Target auth state: UNCHALLENGED
# DEBUG [main] (MainClientExec.java:266) - Proxy auth state: UNCHALLENGED
# DEBUG [main] (LoggingManagedHttpClientConnection.java:133) - http-outgoing-6 >> GET /write-model-as-text-file HTTP/1.1
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-6 >> vector_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/wn18_walks/model.kv
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-6 >> file_to_write: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/wn18_walks/vectors.txt
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-6 >> Host: 127.0.0.1:1808
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-6 >> Connection: Keep-Alive
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-6 >> User-Agent: Apache-HttpClient/4.5.10 (Java/11.0.8)
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-6 >> Accept-Encoding: gzip,deflate
# DEBUG [main] (Wire.java:73) - http-outgoing-6 >> "GET /write-model-as-text-file HTTP/1.1[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-6 >> "vector_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/wn18_walks/model.kv[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-6 >> "file_to_write: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/wn18_walks/vectors.txt[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-6 >> "Host: 127.0.0.1:1808[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-6 >> "Connection: Keep-Alive[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-6 >> "User-Agent: Apache-HttpClient/4.5.10 (Java/11.0.8)[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-6 >> "Accept-Encoding: gzip,deflate[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-6 >> "[\r][\n]"
# Writing the vectors as text file.
# Processing 40961 vectors...
# Vectors processed: 10000 of 40961
# Vectors processed: 20000 of 40961
# Vectors processed: 30000 of 40961
# Vectors processed: 40000 of 40961
# DEBUG [main] (Wire.java:73) - http-outgoing-6 << "HTTP/1.0 200 OK[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-6 << "Content-Type: text/html; charset=utf-8[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-6 << "Content-Length: 4[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-6 << "Server: Werkzeug/1.0.1 Python/3.8.3[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-6 << "Date: Thu, 14 Jan 2021 09:06:05 GMT[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-6 << "[\r][\n]"
# DEBUG [main] (LoggingManagedHttpClientConnection.java:122) - http-outgoing-6 << HTTP/1.0 200 OK
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-6 << Content-Type: text/html; charset=utf-8
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-6 << Content-Length: 4
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-6 << Server: Werkzeug/1.0.1 Python/3.8.3
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-6 << Date: Thu, 14 Jan 2021 09:06:05 GMT
# DEBUG [main] (Wire.java:87) - http-outgoing-6 << "True"
# DEBUG [main] (LoggingManagedHttpClientConnection.java:79) - http-outgoing-6: Close connection
# DEBUG [main] (ConnectionHolder.java:104) - Connection discarded
# DEBUG [main] (PoolingHttpClientConnectionManager.java:349) - Connection released: [id: 6][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:409) - Connection manager is shutting down
# DEBUG [main] (PoolingHttpClientConnectionManager.java:415) - Connection manager shut down
#
# Total Time:
# Days: 0
# Hours: 1
# Minutes: 47
# Seconds: 37
#
#
# Walk Generation Time:
# Days: 0
# Hours: 0
# Minutes: 1
# Seconds: 52
#
#
# Training Time:
# Days: 0
# Hours: 1
# Minutes: 45
# Seconds: 44
#
#  INFO [Thread-0] (Gensim.java:605) - JVM shutdown detected - close python server if still open.
#  INFO [Thread-0] (Gensim.java:607) - Shutdown completed.

# %%
fb15k_walk_path = os.path.join(work_dir, "fb15k_walks")
fb15k_nt_path = os.path.join(nt_dir, "FB15k.nt")

# !jrdf2vec -graph $fb15k_nt_path -numberOfWalks 250 -threads 20 -depth 4 -walkDirectory $fb15k_walk_path -trainingMode sg -dimension 200 -window 2 -epochs 25
# Out:
# The specified walk directory does not exist. Trying to make the directory.
# Using 20 threads for walk generation and training.
# Using vector dimension: 200
# Using depth 4
# Generating 250 walks per entity.
# RDF2Vec Classic
#  INFO [main] (ParserManager.java:53) - Using NxParser.
#  INFO [main] (ParserManager.java:88) - Model read into memory.
# walkGeneration mode is null... Using default: RANDOM_WALKS_DUPLICATE_FREE
#  INFO [pool-1-thread-14] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 1000
#  INFO [pool-1-thread-14] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 250000
#  INFO [pool-1-thread-7] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 2000
#  INFO [pool-1-thread-7] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 499109
#  INFO [pool-1-thread-7] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 3000
#  INFO [pool-1-thread-7] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 748678
#  INFO [pool-1-thread-18] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 4000
#  INFO [pool-1-thread-18] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 998444
#  INFO [pool-1-thread-20] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 5000
#  INFO [pool-1-thread-20] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 1248444
#  INFO [pool-1-thread-14] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 6000
#  INFO [pool-1-thread-14] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 1498247
#  INFO [pool-1-thread-9] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 7000
#  INFO [pool-1-thread-9] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 1747794
#  INFO [pool-1-thread-14] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 8000
#  INFO [pool-1-thread-14] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 1997794
#  INFO [pool-1-thread-7] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 9000
#  INFO [pool-1-thread-7] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 2246148
#  INFO [pool-1-thread-7] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 10000
#  INFO [pool-1-thread-7] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 2495000
#  INFO [pool-1-thread-15] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 11000
#  INFO [pool-1-thread-15] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 2744506
#  INFO [pool-1-thread-6] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 12000
#  INFO [pool-1-thread-6] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 2993650
#  INFO [pool-1-thread-17] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 13000
#  INFO [pool-1-thread-17] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 3243401
#  INFO [pool-1-thread-2] (WalkGenerator.java:320) - TOTAL PROCESSED ENTITIES: 14000
#  INFO [pool-1-thread-2] (WalkGenerator.java:321) - TOTAL NUMBER OF PATHS : 3493182
# DEBUG [main] (RequestAddCookies.java:123) - CookieSpec selected: default
# DEBUG [main] (RequestAuthCache.java:77) - Auth cache not set in the context
# DEBUG [main] (PoolingHttpClientConnectionManager.java:266) - Connection request: [route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:310) - Connection leased: [id: 0][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 1 of 2; total allocated: 1 of 20]
# DEBUG [main] (MainClientExec.java:234) - Opening connection {}->http://127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:139) - Connecting to /127.0.0.1:1808
# DEBUG [main] (LoggingManagedHttpClientConnection.java:96) - http-outgoing-0: Shutdown connection
# DEBUG [main] (ConnectionHolder.java:129) - Connection discarded
# DEBUG [main] (PoolingHttpClientConnectionManager.java:349) - Connection released: [id: 0][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
#  INFO [main] (Gensim.java:582) - Server is not yet running. Waiting 5 seconds. Trial 1 / 8
#  * Serving Flask app "python_server" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# DEBUG [main] (PoolingHttpClientConnectionManager.java:409) - Connection manager is shutting down
# DEBUG [main] (PoolingHttpClientConnectionManager.java:415) - Connection manager shut down
# DEBUG [main] (RequestAddCookies.java:123) - CookieSpec selected: default
# DEBUG [main] (RequestAuthCache.java:77) - Auth cache not set in the context
# DEBUG [main] (PoolingHttpClientConnectionManager.java:266) - Connection request: [route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:310) - Connection leased: [id: 1][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 1 of 2; total allocated: 1 of 20]
# DEBUG [main] (MainClientExec.java:234) - Opening connection {}->http://127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:139) - Connecting to /127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:146) - Connection established 127.0.0.1:53214<->127.0.0.1:1808
# DEBUG [main] (MainClientExec.java:255) - Executing request GET /melt_ml.html HTTP/1.1
# DEBUG [main] (MainClientExec.java:260) - Target auth state: UNCHALLENGED
# DEBUG [main] (MainClientExec.java:266) - Proxy auth state: UNCHALLENGED
# DEBUG [main] (LoggingManagedHttpClientConnection.java:133) - http-outgoing-1 >> GET /melt_ml.html HTTP/1.1
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-1 >> Host: 127.0.0.1:1808
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-1 >> Connection: Keep-Alive
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-1 >> User-Agent: Apache-HttpClient/4.5.10 (Java/11.0.8)
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-1 >> Accept-Encoding: gzip,deflate
# DEBUG [main] (Wire.java:73) - http-outgoing-1 >> "GET /melt_ml.html HTTP/1.1[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-1 >> "Host: 127.0.0.1:1808[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-1 >> "Connection: Keep-Alive[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-1 >> "User-Agent: Apache-HttpClient/4.5.10 (Java/11.0.8)[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-1 >> "Accept-Encoding: gzip,deflate[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-1 >> "[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-1 << "HTTP/1.0 200 OK[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-1 << "Content-Type: text/html; charset=utf-8[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-1 << "Content-Length: 49[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-1 << "Server: Werkzeug/1.0.1 Python/3.8.3[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-1 << "Date: Thu, 14 Jan 2021 14:35:45 GMT[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-1 << "[\r][\n]"
# DEBUG [main] (Wire.java:87) - http-outgoing-1 << "MELT ML Server running. Ready to accept requests."
# DEBUG [main] (LoggingManagedHttpClientConnection.java:122) - http-outgoing-1 << HTTP/1.0 200 OK
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-1 << Content-Type: text/html; charset=utf-8
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-1 << Content-Length: 49
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-1 << Server: Werkzeug/1.0.1 Python/3.8.3
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-1 << Date: Thu, 14 Jan 2021 14:35:45 GMT
#  INFO [main] (Gensim.java:578) - Server is running.
# DEBUG [main] (LoggingManagedHttpClientConnection.java:79) - http-outgoing-1: Close connection
# DEBUG [main] (ConnectionHolder.java:104) - Connection discarded
# DEBUG [main] (PoolingHttpClientConnectionManager.java:349) - Connection released: [id: 1][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# ERROR [main] (Gensim.java:413) - ERROR: The specified model path does not exist or is a directory.
# ERROR [main] (Gensim.java:414) - Provided file path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/fb15k_walks
# DEBUG [main] (RequestAddCookies.java:123) - CookieSpec selected: default
# DEBUG [main] (RequestAuthCache.java:77) - Auth cache not set in the context
# DEBUG [main] (PoolingHttpClientConnectionManager.java:266) - Connection request: [route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:310) - Connection leased: [id: 2][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 1 of 2; total allocated: 1 of 20]
# DEBUG [main] (MainClientExec.java:234) - Opening connection {}->http://127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:139) - Connecting to /127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:146) - Connection established 127.0.0.1:53216<->127.0.0.1:1808
# DEBUG [main] (MainClientExec.java:255) - Executing request GET /train-word2vec HTTP/1.1
# DEBUG [main] (MainClientExec.java:260) - Target auth state: UNCHALLENGED
# DEBUG [main] (MainClientExec.java:266) - Proxy auth state: UNCHALLENGED
# DEBUG [main] (LoggingManagedHttpClientConnection.java:133) - http-outgoing-2 >> GET /train-word2vec HTTP/1.1
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-2 >> vector_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/fb15k_walks/model.kv
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-2 >> model_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/fb15k_walks/model
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-2 >> file_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/fb15k_walks
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-2 >> vector_dimension: 200
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-2 >> number_of_threads: 20
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-2 >> window_size: 2
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-2 >> iterations: 5
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-2 >> negatives: 5
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-2 >> cbow_or_sg: sg
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-2 >> min_count: 1
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-2 >> sample: 0.0
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-2 >> epochs: 25
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-2 >> Host: 127.0.0.1:1808
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-2 >> Connection: Keep-Alive
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-2 >> User-Agent: Apache-HttpClient/4.5.10 (Java/11.0.8)
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-2 >> Accept-Encoding: gzip,deflate
# DEBUG [main] (Wire.java:73) - http-outgoing-2 >> "GET /train-word2vec HTTP/1.1[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 >> "vector_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/fb15k_walks/model.kv[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 >> "model_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/fb15k_walks/model[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 >> "file_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/fb15k_walks[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 >> "vector_dimension: 200[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 >> "number_of_threads: 20[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 >> "window_size: 2[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 >> "iterations: 5[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 >> "negatives: 5[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 >> "cbow_or_sg: sg[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 >> "min_count: 1[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 >> "sample: 0.0[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 >> "epochs: 25[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 >> "Host: 127.0.0.1:1808[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 >> "Connection: Keep-Alive[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 >> "User-Agent: Apache-HttpClient/4.5.10 (Java/11.0.8)[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 >> "Accept-Encoding: gzip,deflate[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 >> "[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 << "HTTP/1.0 200 OK[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 << "Content-Type: text/html; charset=utf-8[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 << "Content-Length: 4[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 << "Server: Werkzeug/1.0.1 Python/3.8.3[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 << "Date: Thu, 14 Jan 2021 14:56:55 GMT[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-2 << "[\r][\n]"
# DEBUG [main] (Wire.java:87) - http-outgoing-2 << "True"
# DEBUG [main] (LoggingManagedHttpClientConnection.java:122) - http-outgoing-2 << HTTP/1.0 200 OK
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-2 << Content-Type: text/html; charset=utf-8
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-2 << Content-Length: 4
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-2 << Server: Werkzeug/1.0.1 Python/3.8.3
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-2 << Date: Thu, 14 Jan 2021 14:56:55 GMT
# DEBUG [main] (LoggingManagedHttpClientConnection.java:79) - http-outgoing-2: Close connection
# DEBUG [main] (ConnectionHolder.java:104) - Connection discarded
# DEBUG [main] (PoolingHttpClientConnectionManager.java:349) - Connection released: [id: 2][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (RequestAddCookies.java:123) - CookieSpec selected: default
# DEBUG [main] (RequestAuthCache.java:77) - Auth cache not set in the context
# DEBUG [main] (PoolingHttpClientConnectionManager.java:266) - Connection request: [route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:310) - Connection leased: [id: 3][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 1 of 2; total allocated: 1 of 20]
# DEBUG [main] (MainClientExec.java:234) - Opening connection {}->http://127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:139) - Connecting to /127.0.0.1:1808
# DEBUG [main] (DefaultHttpClientConnectionOperator.java:146) - Connection established 127.0.0.1:53228<->127.0.0.1:1808
# DEBUG [main] (MainClientExec.java:255) - Executing request GET /write-model-as-text-file HTTP/1.1
# DEBUG [main] (MainClientExec.java:260) - Target auth state: UNCHALLENGED
# DEBUG [main] (MainClientExec.java:266) - Proxy auth state: UNCHALLENGED
# DEBUG [main] (LoggingManagedHttpClientConnection.java:133) - http-outgoing-3 >> GET /write-model-as-text-file HTTP/1.1
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-3 >> vector_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/fb15k_walks/model.kv
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-3 >> file_to_write: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/fb15k_walks/vectors.txt
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-3 >> Host: 127.0.0.1:1808
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-3 >> Connection: Keep-Alive
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-3 >> User-Agent: Apache-HttpClient/4.5.10 (Java/11.0.8)
# DEBUG [main] (LoggingManagedHttpClientConnection.java:136) - http-outgoing-3 >> Accept-Encoding: gzip,deflate
# DEBUG [main] (Wire.java:73) - http-outgoing-3 >> "GET /write-model-as-text-file HTTP/1.1[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 >> "vector_path: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/fb15k_walks/model.kv[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 >> "file_to_write: /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/fb15k_walks/vectors.txt[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 >> "Host: 127.0.0.1:1808[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 >> "Connection: Keep-Alive[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 >> "User-Agent: Apache-HttpClient/4.5.10 (Java/11.0.8)[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 >> "Accept-Encoding: gzip,deflate[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 >> "[\r][\n]"
# Writing the vectors as text file.
# Processing 16267 vectors...
# Vectors processed: 10000 of 16267
# DEBUG [main] (Wire.java:73) - http-outgoing-3 << "HTTP/1.0 200 OK[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 << "Content-Type: text/html; charset=utf-8[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 << "Content-Length: 4[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 << "Server: Werkzeug/1.0.1 Python/3.8.3[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 << "Date: Thu, 14 Jan 2021 14:57:16 GMT[\r][\n]"
# DEBUG [main] (Wire.java:73) - http-outgoing-3 << "[\r][\n]"
# DEBUG [main] (Wire.java:87) - http-outgoing-3 << "True"
# DEBUG [main] (LoggingManagedHttpClientConnection.java:122) - http-outgoing-3 << HTTP/1.0 200 OK
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-3 << Content-Type: text/html; charset=utf-8
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-3 << Content-Length: 4
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-3 << Server: Werkzeug/1.0.1 Python/3.8.3
# DEBUG [main] (LoggingManagedHttpClientConnection.java:125) - http-outgoing-3 << Date: Thu, 14 Jan 2021 14:57:16 GMT
# DEBUG [main] (LoggingManagedHttpClientConnection.java:79) - http-outgoing-3: Close connection
# DEBUG [main] (ConnectionHolder.java:104) - Connection discarded
# DEBUG [main] (PoolingHttpClientConnectionManager.java:349) - Connection released: [id: 3][route: {}->http://127.0.0.1:1808][total kept alive: 0; route allocated: 0 of 2; total allocated: 0 of 20]
# DEBUG [main] (PoolingHttpClientConnectionManager.java:409) - Connection manager is shutting down
# DEBUG [main] (PoolingHttpClientConnectionManager.java:415) - Connection manager shut down
#
# Total Time:
# Days: 0
# Hours: 0
# Minutes: 35
# Seconds: 28
#
#
# Walk Generation Time:
# Days: 0
# Hours: 0
# Minutes: 13
# Seconds: 52
#
#
# Training Time:
# Days: 0
# Hours: 0
# Minutes: 21
# Seconds: 36
#
#  INFO [Thread-0] (Gensim.java:605) - JVM shutdown detected - close python server if still open.
#  INFO [Thread-0] (Gensim.java:607) - Shutdown completed.

# %% [markdown]
# ## Let's Check the Embeddings
#
# ```
# !jrdf2vec -analyzeVocab ./wn18_walks/model.kv ./WN18.nt &> wn_analysis.txt
# !jrdf2vec -analyzeVocab ./fb15k_walks/model.kv ./FB15k.nt &> fb_analysis.txt
#
# ```
# The reports are written to the specified files (`wn_analysis.txt`/`fb_analysis.txt`) as they can be quite long.
# You can find the reports in the walk directories.

# %%
wn18_kv_path = os.path.join(wn18_walk_path, "model.kv")
wn18_analysis_path = os.path.join(wn18_walk_path, "wn_analysis.txt")

# !jrdf2vec -analyzeVocab $wn18_kv_path $wn_nt_path &> $wn18_analysis_path

# %%
fb15k_kv_path = os.path.join(fb15k_walk_path, "model.kv")
fb15k_analysis = os.path.join(fb15k_walk_path, "fb_analysis.txt")

# !jrdf2vec -analyzeVocab $fb15k_kv_path $fb15k_nt_path &> $fb15k_analysis

# %% [markdown]
# ## Let's predict!
# We start by generating the files containing the predictions.

# %%
from kbc_rdf2vec.dataset import DataSet
from kbc_rdf2vec.prediction import PredictionFunctionEnum, PredictionFunction
from kbc_rdf2vec.rdf2vec_kbc import Rdf2vecKbc

import os


def generate_prediction_files() -> None:
    wn_vector_file = wn18_kv_path
    wn_nt_file = wn_nt_path
    fb15k_vector_file = fb15k_kv_path
    fb15k_nt_file = fb15k_nt_path

    # let's make a directory if it does not exist yet
    prediction_path = os.path.join(work_dir, "predictions")
    if not os.path.exists(prediction_path):
        os.makedirs(prediction_path)
    
    # ANN WN
    kbc = Rdf2vecKbc(
        model_path=wn_vector_file,
        data_set=DataSet.WN18,
        n=None,
        prediction_function=PredictionFunctionEnum.ANN,
        file_for_predicate_exclusion=wn_nt_file,
        is_reflexive_match_allowed=False,
    )
    kbc.predict(os.path.join(prediction_path, "wn_ann.txt"))

    # ANN FB
    kbc = Rdf2vecKbc(
        model_path=fb15k_vector_file,
        data_set=DataSet.FB15K,
        n=None,
        prediction_function=PredictionFunctionEnum.ANN,
        file_for_predicate_exclusion=fb15k_nt_file,
        is_reflexive_match_allowed=False,
    )
    kbc.predict(os.path.join(prediction_path, "fb15k_ann.txt"))
    

    # most similar WN
    kbc = Rdf2vecKbc(
        model_path=wn_vector_file,
        n=None,
        data_set=DataSet.WN18,
        file_for_predicate_exclusion=wn_nt_file,
        is_reflexive_match_allowed=False,
        prediction_function=PredictionFunctionEnum.MOST_SIMILAR,
    )
    kbc.predict(os.path.join(prediction_path, "wn_most_similar.txt"))
    
    # most similar FB
    kbc = Rdf2vecKbc(
        model_path=fb15k_vector_file,
        n=None,
        data_set=DataSet.FB15K,
        file_for_predicate_exclusion=fb15k_nt_file,
        is_reflexive_match_allowed=False,
        prediction_function=PredictionFunctionEnum.MOST_SIMILAR,
    )
    kbc.predict(os.path.join(prediction_path, "fb15k_most_similar.txt"))
    
    # avg most similar WN
    kbc = Rdf2vecKbc(
        model_path=wn_vector_file,
        n=None,
        data_set=DataSet.WN18,
        file_for_predicate_exclusion=wn_nt_file,
        is_reflexive_match_allowed=False,
        prediction_function=PredictionFunctionEnum.PREDICATE_AVERAGING_MOST_SIMILAR,
    )
    kbc.predict(os.path.join(prediction_path, "wn_averaged_most_similar.txt"))

    # avg most similar FB
    kbc = Rdf2vecKbc(
        model_path=fb15k_vector_file,
        n=None,
        data_set=DataSet.FB15K,
        file_for_predicate_exclusion=fb15k_nt_file,
        is_reflexive_match_allowed=False,
        prediction_function=PredictionFunctionEnum.PREDICATE_AVERAGING_MOST_SIMILAR,
    )
    kbc.predict(os.path.join(prediction_path, "fb15k_averaged_most_similar.txt")) 
    
    # addition WN
    kbc = Rdf2vecKbc(
        model_path=wn_vector_file,
        n=None,
        data_set=DataSet.WN18,
        file_for_predicate_exclusion=wn_nt_file,
        is_reflexive_match_allowed=False,
        prediction_function=PredictionFunctionEnum.ADDITION,
    )
    kbc.predict(os.path.join(prediction_path, "wn_addition.txt"))

    # addition FB
    kbc = Rdf2vecKbc(
        model_path=fb15k_vector_file,
        n=None,
        data_set=DataSet.FB15K,
        file_for_predicate_exclusion=fb15k_nt_file,
        is_reflexive_match_allowed=False,
        prediction_function=PredictionFunctionEnum.ADDITION,
    )
    kbc.predict(os.path.join(prediction_path, "fb15k_addition.txt"))
    
    # addition FB with reflexive matches allowed
    kbc = Rdf2vecKbc(
        model_path=fb15k_vector_file,
        n=None,
        data_set=DataSet.FB15K,
        file_for_predicate_exclusion=fb15k_nt_file,
        is_reflexive_match_allowed=True,
        prediction_function=PredictionFunctionEnum.ADDITION,
    )
    kbc.predict(os.path.join(prediction_path, "fb15k_reflexive_addition.txt"))
    
    # avg addition WN
    kbc = Rdf2vecKbc(
        model_path=wn_vector_file,
        n=None,
        data_set=DataSet.WN18,
        file_for_predicate_exclusion=wn_nt_file,
        is_reflexive_match_allowed=False,
        prediction_function=PredictionFunctionEnum.PREDICATE_AVERAGING_ADDITION,
    )
    kbc.predict(os.path.join(prediction_path, "wn_averaged_addition.txt"))

    # avg addition FB
    kbc = Rdf2vecKbc(
        model_path=fb15k_vector_file,
        n=None,
        data_set=DataSet.FB15K,
        file_for_predicate_exclusion=fb15k_nt_file,
        is_reflexive_match_allowed=False,
        prediction_function=PredictionFunctionEnum.PREDICATE_AVERAGING_ADDITION,
    )
    kbc.predict(os.path.join(prediction_path, "fb15k_averaged_addition.txt"))
    
    # avg addition FB with reflexive matches allowed
    kbc = Rdf2vecKbc(
        model_path=fb15k_vector_file,
        n=None,
        data_set=DataSet.FB15K,
        file_for_predicate_exclusion=fb15k_nt_file,
        is_reflexive_match_allowed=True,
        prediction_function=PredictionFunctionEnum.PREDICATE_AVERAGING_ADDITION,
    )
    kbc.predict(os.path.join(prediction_path, "fb15k_reflexive_averaged_addition.txt"))
    

generate_prediction_files()
# Out:
# 2021-01-13 15:22:10,626 - kbc_rdf2vec.rdf2vec_kbc - INFO - Gensim vector file detected.
# 2021-01-13 15:22:10,628 - gensim.utils - INFO - loading Word2VecKeyedVectors object from ./wn18_walks/model.kv
# 2021-01-13 15:22:10,993 - gensim.utils - INFO - setting ignored attribute vectors_norm to None
# 2021-01-13 15:22:10,994 - gensim.utils - INFO - loaded ./wn18_walks/model.kv
# Predicting Tails and Heads
#   0%|          | 0/5000 [00:00<?, ?it/s]2021-01-13 15:22:11,270 - gensim.models.keyedvectors - INFO - precomputing L2-norms of word weight vectors
# 100%|██████████| 5000/5000 [08:20<00:00,  9.99it/s]
# 2021-01-13 15:30:31,536 - kbc_rdf2vec.rdf2vec_kbc - INFO - Erroneous Triples: 0
# 2021-01-13 15:30:31,789 - kbc_rdf2vec.rdf2vec_kbc - INFO - Gensim vector file detected.
# 2021-01-13 15:30:31,790 - gensim.utils - INFO - loading Word2VecKeyedVectors object from ./fb15k_walks/model.kv
# 2021-01-13 15:30:31,917 - gensim.utils - INFO - setting ignored attribute vectors_norm to None
# 2021-01-13 15:30:31,919 - gensim.utils - INFO - loaded ./fb15k_walks/model.kv
# Predicting Tails and Heads
#   0%|          | 0/59071 [00:00<?, ?it/s]2021-01-13 15:30:33,346 - gensim.models.keyedvectors - INFO - precomputing L2-norms of word weight vectors
#  48%|████▊     | 28624/59071 [12:46<14:23, 35.27it/s]2021-01-13 15:43:20,373 - kbc_rdf2vec.rdf2vec_kbc - ERROR - Could not process the triple: ['/m/018zsw', '/organization/organization/parent./organization/organization_relationship/parent', '/m/018zqj']
#  59%|█████▉    | 34940/59071 [15:47<13:04, 30.76it/s]2021-01-13 15:46:21,283 - kbc_rdf2vec.rdf2vec_kbc - ERROR - Could not process the triple: ['/m/01qm7', '/education/school_category/schools_of_this_kind', '/m/02gn8s']
#  96%|█████████▋| 56987/59071 [26:04<00:53, 38.88it/s]2021-01-13 15:56:37,650 - kbc_rdf2vec.rdf2vec_kbc - ERROR - Could not process the triple: ['/m/0cv72h', '/american_football/football_player/receiving./american_football/player_receiving_statistics/season', '/m/03gqdq7']
# 100%|██████████| 59071/59071 [26:59<00:00, 36.47it/s]
# 2021-01-13 15:57:33,075 - kbc_rdf2vec.rdf2vec_kbc - ERROR - Erroneous Triples: 3
# 2021-01-13 15:57:33,152 - kbc_rdf2vec.rdf2vec_kbc - INFO - Gensim vector file detected.
# 2021-01-13 15:57:33,153 - gensim.utils - INFO - loading Word2VecKeyedVectors object from ./wn18_walks/model.kv
# 2021-01-13 15:57:33,479 - gensim.utils - INFO - setting ignored attribute vectors_norm to None
# 2021-01-13 15:57:33,481 - gensim.utils - INFO - loaded ./wn18_walks/model.kv
# 2021-01-13 15:57:33,757 - kbc_rdf2vec.prediction - INFO - Initializing AveragePredicatePredictionFunction
# Predicting Tails and Heads
#   0%|          | 0/5000 [00:00<?, ?it/s]2021-01-13 15:57:35,129 - gensim.models.keyedvectors - INFO - precomputing L2-norms of word weight vectors
# 100%|██████████| 5000/5000 [21:14<00:00,  3.92it/s]
# 2021-01-13 16:18:50,081 - kbc_rdf2vec.rdf2vec_kbc - INFO - Erroneous Triples: 0
# 2021-01-13 16:18:50,615 - kbc_rdf2vec.rdf2vec_kbc - INFO - Gensim vector file detected.
# 2021-01-13 16:18:50,616 - gensim.utils - INFO - loading Word2VecKeyedVectors object from ./fb15k_walks/model.kv
# 2021-01-13 16:18:50,953 - gensim.utils - INFO - setting ignored attribute vectors_norm to None
# 2021-01-13 16:18:50,954 - gensim.utils - INFO - loaded ./fb15k_walks/model.kv
# 2021-01-13 16:18:52,192 - kbc_rdf2vec.prediction - INFO - Initializing AveragePredicatePredictionFunction
# 2021-01-13 16:18:55,602 - kbc_rdf2vec.prediction - ERROR - Could not find O/T concept /m/067xd in the embedding space.
# 2021-01-13 16:18:55,634 - kbc_rdf2vec.prediction - ERROR - Could not find O/T concept /m/02rsln_ in the embedding space.
# 2021-01-13 16:18:55,651 - kbc_rdf2vec.prediction - ERROR - Could not find O/T concept /m/0fy_j in the embedding space.
# 2021-01-13 16:18:55,778 - kbc_rdf2vec.prediction - ERROR - Could not find O/T concept /aviation/aircraft_model/aircraft_type in the embedding space.
# Predicting Tails and Heads
#   0%|          | 0/59071 [00:00<?, ?it/s]2021-01-13 16:18:55,925 - gensim.models.keyedvectors - INFO - precomputing L2-norms of word weight vectors
# /work/jportisc/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3334: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /work/jportisc/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  48%|████▊     | 28627/59071 [44:49<47:02, 10.79it/s]  2021-01-13 17:03:45,627 - kbc_rdf2vec.rdf2vec_kbc - ERROR - Could not process the triple: ['/m/018zsw', '/organization/organization/parent./organization/organization_relationship/parent', '/m/018zqj']
#  59%|█████▉    | 34941/59071 [55:12<43:00,  9.35it/s]  2021-01-13 17:14:08,100 - kbc_rdf2vec.rdf2vec_kbc - ERROR - Could not process the triple: ['/m/01qm7', '/education/school_category/schools_of_this_kind', '/m/02gn8s']
#  96%|█████████▋| 56991/59071 [1:30:00<03:12, 10.81it/s]  2021-01-13 17:48:56,585 - kbc_rdf2vec.rdf2vec_kbc - ERROR - Could not process the triple: ['/m/0cv72h', '/american_football/football_player/receiving./american_football/player_receiving_statistics/season', '/m/03gqdq7']
# 100%|██████████| 59071/59071 [1:33:14<00:00, 10.56it/s]
# 2021-01-13 17:52:10,307 - kbc_rdf2vec.rdf2vec_kbc - ERROR - Erroneous Triples: 3
# 2021-01-13 17:52:10,672 - kbc_rdf2vec.rdf2vec_kbc - INFO - Gensim vector file detected.
# 2021-01-13 17:52:10,673 - gensim.utils - INFO - loading Word2VecKeyedVectors object from ./wn18_walks/model.kv
# 2021-01-13 17:52:11,208 - gensim.utils - INFO - setting ignored attribute vectors_norm to None
# 2021-01-13 17:52:11,210 - gensim.utils - INFO - loaded ./wn18_walks/model.kv
# Predicting Tails and Heads
#   0%|          | 0/5000 [00:00<?, ?it/s]2021-01-13 17:52:12,061 - gensim.models.keyedvectors - INFO - precomputing L2-norms of word weight vectors
# 100%|██████████| 5000/5000 [08:16<00:00, 10.07it/s]
# 2021-01-13 18:00:28,641 - kbc_rdf2vec.rdf2vec_kbc - INFO - Erroneous Triples: 0
# 2021-01-13 18:00:28,918 - kbc_rdf2vec.rdf2vec_kbc - INFO - Gensim vector file detected.
# 2021-01-13 18:00:28,919 - gensim.utils - INFO - loading Word2VecKeyedVectors object from ./fb15k_walks/model.kv
# 2021-01-13 18:00:29,245 - gensim.utils - INFO - setting ignored attribute vectors_norm to None
# 2021-01-13 18:00:29,246 - gensim.utils - INFO - loaded ./fb15k_walks/model.kv
# Predicting Tails and Heads
#   0%|          | 0/59071 [00:00<?, ?it/s]2021-01-13 18:00:30,555 - gensim.models.keyedvectors - INFO - precomputing L2-norms of word weight vectors
#  48%|████▊     | 28624/59071 [12:54<14:31, 34.95it/s]2021-01-13 18:13:25,137 - kbc_rdf2vec.rdf2vec_kbc - ERROR - Could not process the triple: ['/m/018zsw', '/organization/organization/parent./organization/organization_relationship/parent', '/m/018zqj']
#  59%|█████▉    | 34940/59071 [15:44<11:39, 34.48it/s]2021-01-13 18:16:15,389 - kbc_rdf2vec.rdf2vec_kbc - ERROR - Could not process the triple: ['/m/01qm7', '/education/school_category/schools_of_this_kind', '/m/02gn8s']
#  96%|█████████▋| 56990/59071 [25:34<00:58, 35.70it/s]2021-01-13 18:26:04,922 - kbc_rdf2vec.rdf2vec_kbc - ERROR - Could not process the triple: ['/m/0cv72h', '/american_football/football_player/receiving./american_football/player_receiving_statistics/season', '/m/03gqdq7']
# 100%|██████████| 59071/59071 [26:30<00:00, 37.13it/s]
# 2021-01-13 18:27:01,296 - kbc_rdf2vec.rdf2vec_kbc - ERROR - Erroneous Triples: 3
# 2021-01-13 18:27:01,452 - kbc_rdf2vec.rdf2vec_kbc - INFO - Gensim vector file detected.
# 2021-01-13 18:27:01,453 - gensim.utils - INFO - loading Word2VecKeyedVectors object from ./fb15k_walks/model.kv
# 2021-01-13 18:27:01,582 - gensim.utils - INFO - setting ignored attribute vectors_norm to None
# 2021-01-13 18:27:01,584 - gensim.utils - INFO - loaded ./fb15k_walks/model.kv
# Predicting Tails and Heads
#   0%|          | 0/59071 [00:00<?, ?it/s]2021-01-13 18:27:03,216 - gensim.models.keyedvectors - INFO - precomputing L2-norms of word weight vectors
#  48%|████▊     | 28625/59071 [13:21<13:58, 36.30it/s]2021-01-13 18:40:25,131 - kbc_rdf2vec.rdf2vec_kbc - ERROR - Could not process the triple: ['/m/018zsw', '/organization/organization/parent./organization/organization_relationship/parent', '/m/018zqj']
#  59%|█████▉    | 34940/59071 [16:09<11:36, 34.64it/s]2021-01-13 18:43:12,718 - kbc_rdf2vec.rdf2vec_kbc - ERROR - Could not process the triple: ['/m/01qm7', '/education/school_category/schools_of_this_kind', '/m/02gn8s']
#  87%|████████▋ | 51520/59071 [23:26<03:22, 37.32it/s]

# %% [markdown]
# ## Let's evaluate!
# Now we just evaluate the files that we have.

# %%
from kbc_evaluation.evaluator import Evaluator, EvaluatorResult 
from kbc_rdf2vec.dataset import DataSet
from typing import List, Tuple
import os

# TODO delete:
work_dir = "/work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files"
prediction_path = os.path.join(work_dir, "predictions")

def evaluate_files() -> List[Tuple[str, EvaluatorResult]]:
    
    result_map = {}
    
    # Let's make a directory for predictions
    evaluation_path = os.path.join(work_dir, "evaluation")
    if not os.path.exists(evaluation_path):
        os.makedirs(evaluation_path)
    
    # evaluation of WN 18
    
    file_to_be_written=os.path.join(evaluation_path, "wn_ann_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "wn_ann.txt"),
        data_set=DataSet.WN18,
        n=10,
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["ANN"] = [results]
    
    
    file_to_be_written=os.path.join(evaluation_path, "wn_most_similar_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "wn_most_similar.txt"),
        data_set=DataSet.WN18,
        n=10,
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H, L)"] = [results]

    
    file_to_be_written=os.path.join(evaluation_path, "wn_averaged_most_similar_result.txt")
    Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "wn_averaged_most_similar.txt"),
        data_set=DataSet.WN18,
        n=10,
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H, AVG(T-H))"] = [results]

    
    file_to_be_written=os.path.join(evaluation_path, "wn_addition_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "wn_addition.txt"),
        data_set=DataSet.WN18,
        n=10
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H + L)"] = [results]
    
    
    file_to_be_written=os.path.join(evaluation_path, "wn_averaged_addition_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "wn_averaged_addition.txt"),
        data_set=DataSet.WN18,
        n = 10
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H + AVG(T-H))"] = [results]
    
    
    # evaluation of fb15k
    

    file_to_be_written=os.path.join(evaluation_path, "fb15k_ann_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "fb15k_ann.txt"),
        data_set=DataSet.FB15K,
        n=10,
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["ANN"].append(results)

    
    file_to_be_written=os.path.join(evaluation_path, "fb15k_most_similar_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "fb15k_most_similar.txt"),
        data_set=DataSet.FB15K,
        n=10
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H, L)"].append(results)

    
    file_to_be_written=os.path.join(evaluation_path, "fb15k_averaged_most_similar_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "fb15k_averaged_most_similar.txt"),
        data_set=DataSet.FB15K,
        n=10,
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H, AVG(T-H))"].append(results)

    
    file_to_be_written=os.path.join(evaluation_path, "fb15k_addition_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "fb15k_addition.txt"),
        data_set=DataSet.FB15K,
        n=10
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H + L)"].append(results)
    

    file_to_be_written=os.path.join(evaluation_path, "fb15k_averaged_addition_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "fb15k_averaged_addition.txt"),
        data_set=DataSet.FB15K,
        n=10
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H + AVG(T-H))"].append(results)
    

    file_to_be_written=os.path.join(evaluation_path, "fb15k_reflexive_addition_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "fb15k_reflexive_addition.txt"),
        data_set=DataSet.FB15K,
        n=10
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H + L) reflexive"] = [None, results]
    

    file_to_be_written=os.path.join(evaluation_path, "fb15k_reflexive_averaged_addition_result.txt")
    results = Evaluator.calculate_results(
        file_to_be_evaluated=os.path.join(prediction_path, "fb15k_reflexive_averaged_addition.txt"),
        data_set=DataSet.FB15K,
        n=10
    )
    Evaluator.write_result_object_to_file(file_to_be_written=file_to_be_written, result_object=results)
    result_map["most_similar(H + AVG(T-H)) reflexive"] = [None, results]

    
    return result_map

    
result_map = evaluate_files()
# Out:
# Reading provided file...
# 2021-01-15 15:26:39,713 - root - INFO - Hits@10 Heads: 2069
# 2021-01-15 15:26:39,716 - root - INFO - Hits@10 Tails: 670
# 2021-01-15 15:26:39,717 - root - INFO - Hits@10 Total: 2739
# Calculating Mean Rank
# 2021-01-15 15:26:40,451 - root - INFO - Mean Head Rank: 668.1978 (0 ignored lines)
# 2021-01-15 15:26:40,452 - root - INFO - Mean Tail Rank: 3208.1964 (0 ignored lines)
# 2021-01-15 15:26:40,453 - root - INFO - Mean rank: 1938.1971; rounded: 1938
# Reading provided file...
# Apply Filtering
# 100%|██████████| 5000/5000 [00:46<00:00, 108.40it/s]
# 2021-01-15 15:27:53,157 - root - INFO - Hits@10 Heads: 2069
# 2021-01-15 15:27:53,161 - root - INFO - Hits@10 Tails: 670
# 2021-01-15 15:27:53,162 - root - INFO - Hits@10 Total: 2739
# Calculating Mean Rank
# 2021-01-15 15:27:53,844 - root - INFO - Mean Head Rank: 668.0548 (0 ignored lines)
# 2021-01-15 15:27:53,846 - root - INFO - Mean Tail Rank: 3208.0692 (0 ignored lines)
# 2021-01-15 15:27:53,846 - root - INFO - Mean rank: 1938.062; rounded: 1938
#
# This is the evaluation of file /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/predictions/wn_ann.txt
#
# Non-filtered Results
# --------------------
# Test set size: 5000
# Hits at 10 (Heads): 2069
# Hits at 10 (Tails): 670
# Hits at 10 (All): 2739
# Relative Hits at 10: 0.2739
# Mean rank (Heads): 668
# Mean rank (Tails): 3208
# Mean rank (All): 1938
#
#
# Filtered Results
# ----------------
# Test set size: 5000
# Hits at 10 (Heads): 2069
# Hits at 10 (Tails): 670
# Hits at 10 (All): 2739
# Relative Hits at 10: 0.2739
# Mean rank (Heads): 668
# Mean rank (Tails): 3208
# Mean rank (All): 1938
#
# Reading provided file...
# 2021-01-15 15:28:17,142 - root - INFO - Hits@10 Heads: 1807
# 2021-01-15 15:28:17,145 - root - INFO - Hits@10 Tails: 1898
# 2021-01-15 15:28:17,146 - root - INFO - Hits@10 Total: 3705
# Calculating Mean Rank
# 2021-01-15 15:28:18,322 - root - INFO - Mean Head Rank: 752.598 (0 ignored lines)
# 2021-01-15 15:28:18,323 - root - INFO - Mean Tail Rank: 704.3598 (0 ignored lines)
# 2021-01-15 15:28:18,324 - root - INFO - Mean rank: 728.4789; rounded: 728
# Reading provided file...
# Apply Filtering
# 100%|██████████| 5000/5000 [00:39<00:00, 127.95it/s]
# 2021-01-15 15:29:23,558 - root - INFO - Hits@10 Heads: 1807
# 2021-01-15 15:29:23,563 - root - INFO - Hits@10 Tails: 1898
# 2021-01-15 15:29:23,564 - root - INFO - Hits@10 Total: 3705
# Calculating Mean Rank
# 2021-01-15 15:29:23,834 - root - INFO - Mean Head Rank: 752.4562 (0 ignored lines)
# 2021-01-15 15:29:23,836 - root - INFO - Mean Tail Rank: 704.2418 (0 ignored lines)
# 2021-01-15 15:29:23,837 - root - INFO - Mean rank: 728.349; rounded: 728
#
# This is the evaluation of file /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/predictions/wn_most_similar.txt
#
# Non-filtered Results
# --------------------
# Test set size: 5000
# Hits at 10 (Heads): 1807
# Hits at 10 (Tails): 1898
# Hits at 10 (All): 3705
# Relative Hits at 10: 0.3705
# Mean rank (Heads): 753
# Mean rank (Tails): 704
# Mean rank (All): 728
#
#
# Filtered Results
# ----------------
# Test set size: 5000
# Hits at 10 (Heads): 1807
# Hits at 10 (Tails): 1898
# Hits at 10 (All): 3705
# Relative Hits at 10: 0.3705
# Mean rank (Heads): 752
# Mean rank (Tails): 704
# Mean rank (All): 728
#
# Reading provided file...
# 2021-01-15 15:30:21,983 - root - INFO - Hits@10 Heads: 1086
# 2021-01-15 15:30:21,985 - root - INFO - Hits@10 Tails: 1181
# 2021-01-15 15:30:21,986 - root - INFO - Hits@10 Total: 2267
# Calculating Mean Rank
# 2021-01-15 15:30:23,090 - root - INFO - Mean Head Rank: 2843.0256 (0 ignored lines)
# 2021-01-15 15:30:23,091 - root - INFO - Mean Tail Rank: 2796.3744 (0 ignored lines)
# 2021-01-15 15:30:23,092 - root - INFO - Mean rank: 2819.7; rounded: 2820
# Reading provided file...
# Apply Filtering
# 100%|██████████| 5000/5000 [01:41<00:00, 49.38it/s]
# 2021-01-15 15:33:29,608 - root - INFO - Hits@10 Heads: 1087
# 2021-01-15 15:33:29,611 - root - INFO - Hits@10 Tails: 1182
# 2021-01-15 15:33:29,612 - root - INFO - Hits@10 Total: 2269
# Calculating Mean Rank
# 2021-01-15 15:33:30,707 - root - INFO - Mean Head Rank: 2842.6978 (0 ignored lines)
# 2021-01-15 15:33:30,708 - root - INFO - Mean Tail Rank: 2796.1042 (0 ignored lines)
# 2021-01-15 15:33:30,709 - root - INFO - Mean rank: 2819.401; rounded: 2819
#
# This is the evaluation of file /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/predictions/wn_most_similar.txt
#
# Non-filtered Results
# --------------------
# Test set size: 5000
# Hits at 10 (Heads): 1807
# Hits at 10 (Tails): 1898
# Hits at 10 (All): 3705
# Relative Hits at 10: 0.3705
# Mean rank (Heads): 753
# Mean rank (Tails): 704
# Mean rank (All): 728
#
#
# Filtered Results
# ----------------
# Test set size: 5000
# Hits at 10 (Heads): 1807
# Hits at 10 (Tails): 1898
# Hits at 10 (All): 3705
# Relative Hits at 10: 0.3705
# Mean rank (Heads): 752
# Mean rank (Tails): 704
# Mean rank (All): 728
#
# Reading provided file...
# 2021-01-15 15:34:06,596 - root - INFO - Hits@10 Heads: 1932
# 2021-01-15 15:34:06,597 - root - INFO - Hits@10 Tails: 2137
# 2021-01-15 15:34:06,598 - root - INFO - Hits@10 Total: 4069
# Calculating Mean Rank
# 2021-01-15 15:34:08,200 - root - INFO - Mean Head Rank: 2105.9414 (0 ignored lines)
# 2021-01-15 15:34:08,201 - root - INFO - Mean Tail Rank: 695.6752 (0 ignored lines)
# 2021-01-15 15:34:08,202 - root - INFO - Mean rank: 1400.8083; rounded: 1401
# Reading provided file...
# Apply Filtering
# 100%|██████████| 5000/5000 [00:46<00:00, 107.37it/s]
# 2021-01-15 15:35:21,551 - root - INFO - Hits@10 Heads: 1932
# 2021-01-15 15:35:21,556 - root - INFO - Hits@10 Tails: 2137
# 2021-01-15 15:35:21,557 - root - INFO - Hits@10 Total: 4069
# Calculating Mean Rank
# 2021-01-15 15:35:22,035 - root - INFO - Mean Head Rank: 2105.7646 (0 ignored lines)
# 2021-01-15 15:35:22,037 - root - INFO - Mean Tail Rank: 695.5568 (0 ignored lines)
# 2021-01-15 15:35:22,038 - root - INFO - Mean rank: 1400.6607; rounded: 1401
#
# This is the evaluation of file /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/predictions/wn_addition.txt
#
# Non-filtered Results
# --------------------
# Test set size: 5000
# Hits at 10 (Heads): 1932
# Hits at 10 (Tails): 2137
# Hits at 10 (All): 4069
# Relative Hits at 10: 0.4069
# Mean rank (Heads): 2106
# Mean rank (Tails): 696
# Mean rank (All): 1401
#
#
# Filtered Results
# ----------------
# Test set size: 5000
# Hits at 10 (Heads): 1932
# Hits at 10 (Tails): 2137
# Hits at 10 (All): 4069
# Relative Hits at 10: 0.4069
# Mean rank (Heads): 2106
# Mean rank (Tails): 696
# Mean rank (All): 1401
#
# Reading provided file...
# 2021-01-15 15:35:45,422 - root - INFO - Hits@10 Heads: 1997
# 2021-01-15 15:35:45,424 - root - INFO - Hits@10 Tails: 2271
# 2021-01-15 15:35:45,425 - root - INFO - Hits@10 Total: 4268
# Calculating Mean Rank
# 2021-01-15 15:35:46,511 - root - INFO - Mean Head Rank: 1710.2162 (0 ignored lines)
# 2021-01-15 15:35:46,515 - root - INFO - Mean Tail Rank: 611.407 (0 ignored lines)
# 2021-01-15 15:35:46,517 - root - INFO - Mean rank: 1160.8116; rounded: 1161
# Reading provided file...
# Apply Filtering
# 100%|██████████| 5000/5000 [00:39<00:00, 127.56it/s]
# 2021-01-15 15:36:53,525 - root - INFO - Hits@10 Heads: 1998
# 2021-01-15 15:36:53,530 - root - INFO - Hits@10 Tails: 2272
# 2021-01-15 15:36:53,531 - root - INFO - Hits@10 Total: 4270
# Calculating Mean Rank
# 2021-01-15 15:36:53,928 - root - INFO - Mean Head Rank: 1710.0456 (0 ignored lines)
# 2021-01-15 15:36:53,929 - root - INFO - Mean Tail Rank: 611.2902 (0 ignored lines)
# 2021-01-15 15:36:53,930 - root - INFO - Mean rank: 1160.6679; rounded: 1161
#
# This is the evaluation of file /work/jportisc/kbc_rdf2vec/strategy_grid_2/notebook_files/predictions/wn_averaged_addition.txt
#
# Non-filtered Results
# --------------------
# Test set size: 5000
# Hits at 10 (Heads): 1997
# Hits at 10 (Tails): 2271
# Hits at 10 (All): 4268
# Relative Hits at 10: 0.4268
# Mean rank (Heads): 1710
# Mean rank (Tails): 611
# Mean rank (All): 1161
#
#
# Filtered Results
# ----------------
# Test set size: 5000
# Hits at 10 (Heads): 1998
# Hits at 10 (Tails): 2272
# Hits at 10 (All): 4270
# Relative Hits at 10: 0.427
# Mean rank (Heads): 1710
# Mean rank (Tails): 611
# Mean rank (All): 1161
#
# Reading provided file...

# %% [markdown]
# ## Let's Render our Evaluation Results
# We have already individual evaluation files written to disk. Now, let's quickly render an HTML table.

# %%
from IPython.display import display, HTML
from typing import Dict

def transform_result_list_to_html(result_map: List[Dict[str, List[EvaluatorResult]]]) -> str:
    
    first_entry = next(iter(result_map.values()))
    
    if first_entry[0].n is not None:
        n = first_entry[0].n
    elif first_entry[1].n is not None:
        n = first_entry[1].n
    else:
        n = "?"
    
    
    result = f"""
        <table style="border: 1px solid black;">
            <tr>
                <td>&nbsp;</td>
                <td colspan="6"><center><b>WN18</b></center></td>
                <td colspan="6"><center><b>FB15k</b></center></td>
            </tr>
            <tr>
                <td>Metric</td>
                <td colspan="2"><center>Mean Rank</center></td>
                <td colspan="2"><center>HITS@{n}</center></td>
                <td colspan="2"><center>RelativeHITS@{n}</center></td>
                <td colspan="2"><center>Mean Rank</center></td>
                <td colspan="2"><center>HITS@{n}</center></td>
                <td colspan="2"><center>RelativeHITS@{n}</center></td>
            <tr>
            <tr>
                <td>Evaluation Setting</td>
                <td>Raw</td>
                <td>Filtered</td>
                <td>Raw</td>
                <td>Filtered</td>
                <td>Raw</td>
                <td>Filtered</td>
                <td>Raw</td>
                <td>Filtered</td>
                <td>Raw</td>
                <td>Filtered</td>
                <td>Raw</td>
                <td>Filtered</td>
            </tr>
        """    
    
    for setting, entry in result_map.items():
        result = result + f"""
            <tr>
                <td>{setting}</td>
            """
        if entry[0] is not None:
            result = result + f"""
                <td>{entry[0].non_filtered_mean_rank_all}</td>
                <td>{entry[0].filtered_mean_rank_all}</td>
                <td>{entry[0].non_filtered_hits_at_n_all}</td>
                <td>{entry[0].filtered_hits_at_n_all}</td>
                <td>{round(entry[0].non_filtered_hits_at_n_relative, 4)}</td>
                <td>{round(entry[0].filtered_hits_at_n_relative, 4)}</td>
            """
        else:
            result = result + f"""
                <td>&nbsp;</td>
                <td>&nbsp;</td>
                <td>&nbsp;</td>
                <td>&nbsp;</td>
            """
        if entry [1] is not None:
            result = result + f"""
                <td>{entry[1].non_filtered_mean_rank_all}</td>
                <td>{entry[1].filtered_mean_rank_all}</td>
                <td>{entry[1].non_filtered_hits_at_n_all}</td>
                <td>{entry[1].filtered_hits_at_n_all}</td>
                <td>{round(entry[1].non_filtered_hits_at_n_relative, 4)}</td>
                <td>{round(entry[1].filtered_hits_at_n_relative, 4)}</td>
            """
        else:
             result = result + f"""
                <td>&nbsp;</td>
                <td>&nbsp;</td>
                <td>&nbsp;</td>
                <td>&nbsp;</td>
            """
        
        result = result + "</tr>"
        
    
    result = result + "\n</table>"
    return result


display(HTML(transform_result_list_to_html(result_map)))
# Out:
#         <table style="border: 1px solid black;">
#             <tr>
#                 <td>&nbsp;</td>
#                 <td colspan="6"><center><b>WN18</b></center></td>
#                 <td colspan="6"><center><b>FB15k</b></center></td>
#             </tr>
#             <tr>
#                 <td>Metric</td>
#                 <td colspan="2"><center>Mean Rank</center></td>
#                 <td colspan="2"><center>HITS@10</center></td>
#                 <td colspan="2"><center>RelativeHITS@10</center></td>
#                 <td colspan="2"><center>Mean Rank</center></td>
#                 <td colspan="2"><center>HITS@10</center></td>
#                 <td colspan="2"><center>RelativeHITS@10</center></td>
#             <tr>
#             <tr>
#                 <td>Evaluation Setting</td>
#                 <td>Raw</td>
#                 <td>Filtered</td>
#                 <td>Raw</td>
#                 <td>Filtered</td>
#                 <td>Raw</td>
#                 <td>Filtered</td>
#                 <td>Raw</td>
#                 <td>Filtered</td>
#                 <td>Raw</td>
#                 <td>Filtered</td>
#                 <td>Raw</td>
#                 <td>Filtered</td>
#             </tr>
#
#             <tr>
#                 <td>ANN</td>
#
#                 <td>1938</td>
#                 <td>1938</td>
#                 <td>2739</td>
#                 <td>2739</td>
#                 <td>0.2739</td>
#                 <td>0.2739</td>
#
#                 <td>346</td>
#                 <td>343</td>
#                 <td>43229</td>
#                 <td>43614</td>
#                 <td>0.3659</td>
#                 <td>0.3692</td>
#             </tr>
#             <tr>
#                 <td>most_similar(H + L)</td>
#
#                 <td>728</td>
#                 <td>728</td>
#                 <td>3705</td>
#                 <td>3705</td>
#                 <td>0.3705</td>
#                 <td>0.3705</td>
#
#                 <td>346</td>
#                 <td>343</td>
#                 <td>43229</td>
#                 <td>43614</td>
#                 <td>0.3659</td>
#                 <td>0.3692</td>
#             </tr>
# </table>

# %%
# Out:
# 10
